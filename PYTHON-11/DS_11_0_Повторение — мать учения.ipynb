# %% [markdown]
# # 0. Повторение — мать учения
#
# ✍ В прошлом модуле мы рассмотрели основные структуры данных в Pandas, научились выводить информацию о таблице, получать статистические характеристики столбцов и фильтровать данные. Прежде чем приступить к дальнейшему рассмотрению библиотеки, предлагаем вам пройти небольшой тест, чтобы освежить знания ↓
