# %% [markdown]
# # PYTHON-15. Принципы ООП в Python и отладка кода

# %% [markdown]
# ## 1. Введение

# %% [markdown]
# Ещё со времён изучения биологии вы, должно быть, помните похожие изображения:
#
#
#
# Источник
#
# Мы видим, что класс млекопитающих делится на подклассы, каждый из которых обладает своим определённым набором свойств и качеств.
#
# Что же отличает человека от черепашек (даже если это черепашки-ниндзя)?

# %% [markdown]
# Идеология объектно-ориентированного программирования (ООП) разрабатывалась как попытка связать поведение определённой сущности (объекта) с тем, к какому классу она принадлежит. Причина задумки такого подхода в том, что нам проще воспринимать окружающий мир как объекты, которые поддаются определённой классификации (взять хотя бы разделение на живую и неживую природу).
#
# Однако не стоит думать, что применение какой-либо из концепций упростит написание (создание) кода. Оно скорее будет влиять на последующее обслуживание и возможность масштабирования. ООП — не исключение.
#
# Основу ООП составляют два понятия — классы и объекты.

# %% [markdown]
# Посмотрим на человека? У него есть некоторые свойства, которые определяют наш внешний облик как вида — две руки, две ноги, определённый набор костей, мышцы и так далее.
#
# Когда мы говорим о классе, мы имеем в виду то, какими свойствами и поведением будет обладать объект (например, ходить на двух ногах, говорить).
#
# А объект — это экземпляр с собственным состоянием этих свойств (то, что будет отличать одного человека от другого), любой предмет, существо, явление. Иными словами, это всё, что называется именем существительным, о чём можно сказать «это что-то» или «это кто-то».

# %% [markdown]
# Так и в программировании: мы создаём классы, то есть описываем свойства, которыми будут обладать объекты, принадлежащие этому классу.
#
# ✍️ В этом модуле мы узнаем, как использовать ООП в Python. Мы обсудим:
#
# что такое объект и класс, как их определять и из каких элементов они состоят;
# несколько практических примеров, где ООП помогает эффективнее решать задачу;
# как организовать хранение классов во многих файлах.
# Для прохождения модуля вам понадобится знание функций и базовых конструкций в Python.

# %% [markdown]
# Если хотите подробнее разобраться с ООП, почитайте Erric Matthes (для начинающих) и Dusty Phillips OOP in Python 3 (руководство с практическими примерами на все случаи жизни).

# %% [markdown]
# Мы уже упоминали, что объекты класса обладают свойствами и поведением (методами).
#
# ?
# В чём разница между свойствами и методами?

# %% [markdown]
# В сравнении двух изображений видно, что свойствам устанавливаются значения, а методам — нет. То есть методы — это определённое поведение, которым характеризуется объект, а свойства могут изменяться.

# %% [markdown]
# ## 2. Принципы ООП

# %% [markdown]
# ООП, как и любой другой тип, характеризуется своими особенностями (принципами). Рассмотрим их подробнее.
#
# Не бойтесь сложных и непонятных вам слов! Помните: однажды они обязательно пригодятся вам в высокообразованных спорах с опытными программистами или же коллегами.

# %% [markdown]
# ### Наследование
#
# Этот принцип базируется на том, что новый класс описывается на основе уже существующего (родительского), то есть не только перенимает все свойства родительского класса, но ещё и получает новые.
#
# Для примера снова посмотрим на класс животных. Млекопитающие и рептилии являются животными, но мы точно сможем сказать, чем млекопитающее отличается от рептилии. То есть помимо одинаковых свойств и поведения, они имеют свои специфические.
#
# Или пойдём ещё дальше: в животных выделим собаку и лошадь. Вроде бы тоже перенимают все свойства млекопитающих, животных, но каждый из них добавляет ещё свои новые свойства. Это и есть наследование.

# %% [markdown]
# ### Абстракция
#
# Абстракция означает выделение главных, наиболее значимых характеристик предмета и, наоборот, отбрасывание второстепенных, незначительных.
#
# Например, в каждой компании в отделе кадров есть картотека по сотрудникам. Но если мы сравним картотеку IT-компании и базу артистов театра и кино, то поймем, что указаны там, скорее всего, разные свойства людей. Вряд ли для IT-компании важен будет типаж человека (цвет волос, глаз и так далее), а вот для компании, которая занимается съёмкой фильмов, возможно, это будет приоритетнее, чем, например, номер ИНН.

# %% [markdown]
# ### Инкапсуляция
#
# Это свойство системы, позволяющее объединить данные и методы, работающие с ними, в классе и скрыть детали реализации от пользователя. Инкапсуляция также означает ограничение доступа к данным и возможностям их изменения.
#
# В основе лежит слово «капсула». В эту «капсулу» мы прячем какие-то важные для нас данные, которые не хотим, чтобы кто-то менял. Например, имя и фамилию. Изменить их может только сам человек, пройдя определенные процедуры. У любого другого человека нет возможности просто так взять и поменять чужое имя (ну если только не придумать прозвище).
#
# В программировании есть свойства, которые можно изменять, но есть и такие, которые пользователь не может изменить. Например, можно наложить ограничение на изменяемость уникального идентификатора у класса пользователя.
#
# Также инкапсуляция заключается и в возможности наложения ограничения на вводимые данные. Допустим, есть класс people, одним из свойств которого является age. Мы знаем, что возраст — положительное значение. Инкапсуляция в данном случае будет означать, что отрицательное значение возраста ввести не получится.

# %% [markdown]
# ### Полиморфизм
#
# Это свойство системы, позволяющее иметь множество реализаций одного интерфейса.
#
# Понятнее будет на примере. У нас есть два разных автомобиля, но мы точно знаем: чтобы повернуть налево, нужно повернуть налево и руль. Это и есть одинаковость интерфейса, а вот есть там гидроусилитель или нет — различие реализации.

# %% [markdown]
# ## 3. Объекты и классы

# %% [markdown]
# ### Объекты
#
# Некоторые данные и действия над ними могут объединяться вместе в единый объект. В Python всё по сути является объектом. Объект числа хранит своё значение — данные, мы можем вызвать его методы, совершать действия.

# %%
number = 2.5   
# Вызовем метод is_integer. Он скажет нам, является ли number целым числом  
print(number.is_integer())  
# => False  
  
# Давайте попробуем представить number как обыкновенную дробь  
print(number.as_integer_ratio())  
# => (5, 2)  
# Действительно 2.5 = 5/2
# Out:
# False
# (5, 2)

# %% [markdown]
# Посмотрим на список: он хранит данные своих элементов, мы можем совершать над ними действия встроенными методами.

# %%
 people = ["Vasiliy", "Stanislav", "Alexandra", "Vasiliy"]  
  
# Посчитаем число Василиев с помощью метода count  
print(people.count("Vasiliy"))  
# => 2  
  
# Теперь отсортируем   
people.sort()  
print(people)  
# => ['Alexandra', 'Stanislav', 'Vasiliy', 'Vasiliy']
# Out:
# 2
# ['Alexandra', 'Stanislav', 'Vasiliy', 'Vasiliy']

# %% [markdown]
# ### Классы
#
# У всех встроенных объектов есть свой класс. В примере для числа 2.5 мы видим класс действительных чисел (float), для списка — класс списка (list). Класс — это некая заготовка или чертёж, которая описывает общую структуру, свойства и действия для объектов.

# %%
 number = 2.5  
print(number.__class__)  
# => <class 'float'>  
  
people = ["Vasiliy", "Stanislav", "Alexandra", "Vasiliy"]  
print(people.__class__)  
# => <class 'list'>
# Out:
# <class 'float'>
# <class 'list'>

# %% [markdown]
# Определим пустой класс: он не делает ничего, но позволит нам посмотреть на синтаксис.

# %%
 # Используем ключевое слово class, за которым идёт название класса, в примере это SalesReport  
class SalesReport():  
    pass  
  
# Сравните это с определением пустой функции  
# Команда pass не делает ничего; на её месте могли быть другие инструкции  
# Мы используем её только потому, что синтаксически python требует, чтобы там было хоть что-то  
def build_report():  
    pass  
  
  
# И давайте определим ещё один класс  
# Для имён классов традиционно используются имена в формате CamelCase, где начала слов отмечаются большими буквами  
# Это позволяет легко отличать их от функций, которые пишутся в формате snake_case  
class SkillfactoryStudent():  
    pass

# %% [markdown]
# ### Объекты из классов
#
# Мы написали свой первый класс — давайте создадим по нему объект. Вызываем класс и получаем новый объект аналогично тому, как вызывается функция. Получаем результат.

# %%
 class SalesReport():  
    pass  
  
# создаём объект по классу  
report = SalesReport()  
  
# мы можем создавать множество объектов по одному классу  
report_2 = SalesReport()  
  
# Это будут разные объекты.   
print(report == report_2)  
# => False
# Out:
# False

# %% [markdown]
# Созданный таким образом объект часто называют экземпляром класса (instance). Такое название вы будете часто встречать в статьях и книгах.

# %% [markdown]
# ## 4. Атрибуты и методы

# %% [markdown]
# ### Атрибуты и методы
#
# Мы создали объект по пустому классу. Давайте добавим ему данные. Сделаем класс для отчётов по продажам SalesReport. Пусть у нас в компании есть менеджеры по продажам, которые заключают сделки, и мы хотим посчитать для них метрики общего объёма продаж.

# %%
 # По-прежнему пока создаём пустой класс  
class SalesReport():  
    pass  
  
# Создаём первый отчёт по продажам   
report = SalesReport()  
  
# Мы добавим новый атрибут объекту.  
# Для этого через точку напишем имя атрибута и дальше как с обычной переменной  
report.amount = 10  
  
# То же самое делаем для второго отчёта.  
report_2 = SalesReport()  
report_2.amount = 20  
  
# Создадим вспомогательную функцию, она будет печатать общую сумму из отчёта  
def print_report(report):  
    print("Total amount:", report.amount)  
      
print_report(report) # => Total amount: 10  
print_report(report_2) # => Total amount: 20
# Out:
# Total amount: 10
# Total amount: 20

# %% [markdown]
# Для разных отчётов вывелись разные значения, хотя объекты создавались из одного класса. Функция print_report делает операцию над отчётом. Так как классы увязывают данные и действия над ними, положим print_report внутрь класса.

# %%
 class SalesReport():  
    # Наш новый метод внутри класса.  
    # Мы определяем его похожим образом с обычными функциями,  
    #   но только помещаем внутрь класса и первым аргументом передаём self  
    def print_report(self):  
        print("Total amount:", self.amount)  
          
          
# Дальше мы применяем report так же, как и в примере выше   
report = SalesReport()  
report.amount = 10  
  
report_2 = SalesReport()  
report_2.amount = 20  
  
# Используем наши новые методы  
report.print_report() # => Total amount: 10  
report_2.print_report() # => Total amount: 20
# Out:
# Total amount: 10
# Total amount: 20

# %% [markdown]
# Мы определили метод внутри класса, и он стал доступен у всех экземпляров этого класса.
#
# Методы в целом похожи на обычные функции, но их ключевое отличие — доступ к самому объекту.

# %% [markdown]
# В методе мы первым аргументом получаем self — в нашем случае это отчёт, что позволяет использовать атрибуты объекта внутри метода, как мы сделали с amount. Self передаётся автоматически. При вызове метода мы не передавали никакие аргументы.
#
# Давайте для примера определим ещё пару методов:

# %%
 class SalesReport():  
    # Позволим добавлять много разных сделок   
    def add_deal(self, amount):   
        # На первой сделке создадим список для хранения всех сделок   
        if not hasattr(self, 'deals'):  
            self.deals = []  
        # Добавим текущую сделку  
        self.deals.append(amount)  
          
    # Посчитаем сумму всех сделок      
    def total_amount(self):  
        return sum(self.deals)  
      
    def print_report(self):  
        print("Total sales:", self.total_amount())  
          
# Используем наши новые возможности  
# Добавим две сделки и распечатаем отчёт  
report = SalesReport()  
report.add_deal(10_000)  
report.add_deal(30_000)  
report.print_report() # => Total sales: 40000
# Out:
# Total sales: 40000

# %% [markdown]
# Атрибут deals, определённый в одном методе, становится доступен сразу во всех методах класса. Через self становятся доступны и остальные методы, например print_report использует метод total_amount. Это позволяет компактно упаковывать логику внутри класса: внешнее использование становится гораздо лаконичнее.

# %% [markdown]
# ### Задание 4.1 (External resource)
# (1.0 points possible)
#
# Допишите определение класса DepartmentReport, который выводит отчёт по отделам компании. У него должны быть определены:
#
# свойство revenues — список, где мы храним значения выручки отделов;
# метод add_revenue(), который добавляет выручку одного отдела в список revenues. Если списка revenues еще не существует, метод должен его создавать (проверку наличия атрибута можно выполнить с помощью встроенной функции hasattr());
# метод average_revenue(), который возвращает среднюю выручку по всем отделам (считает среднее по списку revenues).
# Пример использования класса:
#
#
# report = DepartmentReport()
# report.add_revenue(1_000_000)
# report.add_revenue(400_000)
# print(report.revenues)
# # [1000000, 400000]
# print(report.average_revenue())
# # 700000.0
# Обратите внимание, что от вас требуется только объявить класс. Создавать экземпляров класса не нужно!

# %%
class DepartmentReport():
       
    def add_revenue(self, amount):
        """
        Метод для добавления выручки отдела в список revenues.
        Если атрибута revenues ещё не существует, метод должен создавать пустой список перед добавлением выручки.
        """
        # ваш код здесь
            # На первой сделке создадим список для хранения всех сделок   
        if not hasattr(self, 'revenues'):  
            self.revenues = []  
        # Добавим текущую сделку  
        self.revenues.append(amount) 
    
    def average_revenue(self):
        """
        Метод возвращает среднюю выручку по отделам.
        """
        # ваш код здесь
        return  sum(self.revenues) / len(self.revenues)

# %% [markdown]
# ### Метод _INIT_
#
# Мы определили несколько методов в классе SalesReport. С ним есть пара проблем.
#
# Если мы вызовем total_amount до add_deal, то список сделок ещё не будет создан, и мы получим ошибку. Также проверка на наличие списка в методе add_deal не кажется оптимальным решением, потому что создать список нужно один раз, а проверять его наличие мы вынуждены на каждой сделке.

# %%
 class SalesReport():  
    def add_deal(self, amount):   
        if not hasattr(self, 'deals'):  
            self.deals = []  
        self.deals.append(amount)  
          
    def total_amount(self):  
        return sum(self.deals)  
      
    def print_report(self):  
        print("Total sales:", self.total_amount())  
          
report = SalesReport()  
report.total_amount()  
# => AttributeError
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[11], line 14
#      11        print("Total sales:", self.total_amount())
#      13 report = SalesReport()
# ---> 14 report.total_amount()
#      15 # => AttributeError
#
# Cell In[11], line 8, in SalesReport.total_amount(self)
#       7 def total_amount(self):
# ----> 8     return sum(self.deals)
#
# AttributeError: 'SalesReport' object has no attribute 'deals'

# %% [markdown]
# Обе проблемы решились бы, если задавать атрибутам исходное значение. Для этого у классов есть метод инициализации __init__. Если мы определим метод с таким именем, код в нём вызовется при создании объекта.

# %%
 class SalesReport():  
    def __init__(self):  
        self.deals = []  
          
    def add_deal(self, amount):   
        self.deals.append(amount)  
          
    def total_amount(self):  
        return sum(self.deals)  
      
    def print_report(self):  
        print("Total sales:", self.total_amount())  
   
report = SalesReport()  
print(report.deals)  
# => []  
report.total_amount()  
# => 0
# Out:
# []
# 0

# %% [markdown]
# При создании отчёта вызвался __init__, deals определился в нём пустым списком и проблемы ушли.
#
# __init__ — это технический метод, поэтому его имя начинается и заканчивается двумя подчёркиваниями. Он получает первым аргументом сам объект, в нём могут выполняться любые операции. Оставшиеся аргументы он получает из вызова при создании: если мы напишем report = SalesReport("Info", 20), то вторым и третьим аргументом в __init__ передадутся "Info" и 20.

# %%
 class SalesReport():  
    # Будем принимать в __init__ ещё и имя менеджера  
    def __init__(self, manager_name):  
        self.deals = []  
        self.manager_name = manager_name  
          
    def add_deal(self, amount):   
        self.deals.append(amount)  
          
    def total_amount(self):  
        return sum(self.deals)  
      
    def print_report(self):  
        # И добавлять это имя в отчёт  
        print("Manager:", self.manager_name)  
        print("Total sales:", self.total_amount())  
          
   
report = SalesReport("Ivan Taranov")  
report.add_deal(10_000)  
report.add_deal(30_000)  
report.print_report()  
# =>   
# Manager: Ivan Taranov  
# Total sales: 40000
# Out:
# Manager: Ivan Taranov
# Total sales: 40000

# %% [markdown]
# Кроме __init__ у классов можно определить ряд технических методов, которые также называют магическими. Дело в том, что они не вызываются напрямую, но позволяют реализовать операции сложения object_1 + object_2 или сравнения object_1 > object_2.
#
# Они используются реже __init__, так что мы оставим их за скобками модуля. При желании полный список можно найти в документации.

# %% [markdown]
# ### Задание 4.2 (External resource)
# (1.0 points possible)
#
# Улучшите класс DepartmentReport, добавив в него инициализатор.
#
# Класс при инициализации должен принимать переменную company_name и инициализировать её значением свойство company, а также инициализировать свойство revenues пустым списком.
#
# Также модифицируйте метод average_revenue. Теперь он должен возвращать строку следующего вида "Average department revenue for <company_name>: <average_revenue>".
#
# Пример использования класса:
#
#
# report = DepartmentReport(company_name="Danon")
# print(report.company)
# # Danon
#
# report.add_revenue(1_000_000)
# report.add_revenue(400_000)
#
# print(report.average_revenue())
# # Average department revenue for Danon: 700000
# Обратите внимание, что от вас требуется только объявить класс. Создавать экземпляров класса не нужно!

# %%
class DepartmentReport():

    def __init__(self, company_name):
        """
        Метод инициализации класса. 
        Создаёт атрибуты revenues и company
        """
        #ваш код здесь
        self.revenues = []  
        self.company = company_name
   
    def add_revenue(self, amount):
        """
        Метод для добавления выручки отдела в список revenues.
        """
        # ваш код здесь
        # Добавим текущую сделку  
        self.revenues.append(amount) 
    
    def average_revenue(self):
        """
        Метод возвращает среднюю выручку по отделам.
        """
        
        # ваш код здесь
        average_revenue = round(sum(self.revenues) / len(self.revenues))
        return  f"Average department revenue for {self.company}: {average_revenue}"

# %% [markdown]
# ### краткое резюме
#
# ✔️ Мы рассмотрели базовый синтаксис классов и синтаксис создания объектов. Давайте вспомним некоторые важные моменты:
#
# атрибут объекта — это просто его переменная;
# метод объекта — это его функция;
# метод объекта автоматически получает первым аргументом сам объект под именем self;
# класс описывает объект через его атрибуты и методы;
# мы можем создавать множество экземпляров одного класса, и значения их атрибутов независимы друг от друга;
# если определить метод __init__, то он будет выполняться при создании объекта;
# всё это позволяет компактно увязывать данные и логику внутри объекта.
# Чтобы продемонстрировать, что мы имеем в виду под компактностью, давайте добавим ещё метрик в отчёт.
#
# Допустим, теперь мы хотим получать средний размер сделки и список клиентов, из которого исключены повторения (в случае, если компания заключала несколько сделок с одним и тем же клиентом).

# %%
class SalesReport():  
    def __init__(self, employee_name):  
        self.deals = []  
        self.employee_name = employee_name  
      
    def add_deal(self, company, amount):   
        self.deals.append({'company': company, 'amount': amount})  
          
    def total_amount(self):  
        return sum([deal['amount'] for deal in self.deals])  
      
    def average_deal(self):  
        return self.total_amount()/len(self.deals)  
      
    def all_companies(self):  
        return list(set([deal['company'] for deal in self.deals]))  
      
    def print_report(self):  
        print("Employee: ", self.employee_name)  
        print("Total sales:", self.total_amount())  
        print("Average sales:", self.average_deal())  
        print("Companies:", self.all_companies())  
      
      
report = SalesReport("Ivan Semenov")  
  
report.add_deal("PepsiCo", 120_000)  
report.add_deal("SkyEng", 250_000)  
report.add_deal("PepsiCo", 20_000)  
  
report.print_report()  
# => Employee:  Ivan Semenov  
# Total sales: 390000  
# Average sales: 130000.0  
# Companies: ['PepsiCo', 'SkyEng']
# Out:
# Employee:  Ivan Semenov
# Total sales: 390000
# Average sales: 130000.0
# Companies: ['PepsiCo', 'SkyEng']

# %% [markdown]
# Мы расширили отчёт, но внешний код использования классов не увеличился. Отчёт, который мы вывели, достаточно простой, но можно автоматически генерировать презентацию с данными и графиками в PDF, при этом внешний интерфейс не менялся бы. Мы просто передаём данные на вход и на выходе получаем отчёт.

# %% [markdown]
# ## 5. Практические примеры

# %% [markdown]
# ⭐️ Мы научились определять классы и создавать объекты. Основная их задача — объединять данные и действия над ними. Эти же задачи можно решать обычными функциями и коллекциями (словарями/списками).
#
# Разница в том, что для ряда задач ООП является более подходящим инструментом и позволяет решать их проще. Рассмотрим ещё несколько примеров — это поможет вам развить интуицию и понять, в каких ситуациях стоит рассматривать переход от простых функций к классам.

# %% [markdown]
# ### Отслеживание состояния
#
# Одно из классических предписаний для классов — у каждого из множества объектов есть некоторые меняющиеся состояния.
#
# Вернёмся к примеру: есть база клиентов с основной информацией; в реальном времени нам приходит информация о покупках. Запустим промокампанию, чтобы поощрить старых клиентов, которые сделали у нас много заказов, и выдать им скидку:

# %%
class Client():  
    # Базовые данные  
    def __init__(self, email, order_num, registration_year):  
        self.email = email  
        self.order_num = order_num  
        self.registration_year = registration_year  
        self.discount = 0  
          
    # Оформление заказа  
    def make_order(self, price):  
        self.update_discount()  
        self.order_num += 1  
        # Здесь было бы оформление заказа, но мы просто выведем его цену  
        discounted_price = price * (1 - self.discount)   
        print(f"Order price for {self.email} is {discounted_price}")  
              
    # Назначение скидки  
    def update_discount(self):   
        if self.registration_year < 2018 and self.order_num >= 5:  
            self.discount = 0.1   
              
  
# Применение  
          
# Сделаем подобие базы  
client_db = [   
    Client("max@gmail.com", 2, 2019),  
    Client("lova@yandex.ru", 10, 2015),  
    Client("german@sberbank.ru", 4, 2017)  
]  
  
  
# Сгенерируем заказы  
client_db[0].make_order(100)  
# => Order price for max@gmail.com is 100  
  
client_db[1].make_order(200)  
# => Order price for lova@yandex.ru is 180.0  
  
client_db[2].make_order(500)  
# => Order price for german@sberbank.ru is 500  
  
client_db[2].make_order(500)  
# => Order price for german@sberbank.ru is 450.0
# Out:
# Order price for max@gmail.com is 100
# Order price for lova@yandex.ru is 180.0
# Order price for german@sberbank.ru is 500
# Order price for german@sberbank.ru is 450.0

# %% [markdown]
# Два важных момента:
#
# У нас получился простой интерфейс. С функциями нам пришлось бы передавать много параметров или делать вложенный словарь.
# В классах хорошо реализуется скрытая логика и естественное сохранение состояний. В примере на втором и четвёртом заказах автоматически появилась скидка.

# %% [markdown]
# ### Задание 5.1 (External resource)
#
# Мы разрабатываем приложение, которое подразумевает функционал авторизации пользователя, а также управление его балансом на некотором виртуальном счете.
#
# Определите класс для пользователей User.
#
# У него должны быть:
#
# атрибуты email, password и balance, которые устанавливаются при инициализации в методе __init__();
# метод login(), который реализует проверку почты и пароля. Метод должен принимать в качестве аргументов емайл (email) и пароль (password). Если они совпадают с атрибутами объекта, он возвращает True, а иначе — False;
# метод update_balance(), который должен принимать в качестве аргумента amount некоторое число и изменять текущий баланс счёта (атрибут balance) на величину amount.
# В случае правильного описания класса код, приведённый ниже, должен выдать следующий результат:
#
# Пример использования класса:
#
#
# user = User("gosha@roskino.org", "qwerty", 20_000)
# print(user.login("gosha@roskino.org", "qwerty123"))
# # False
# print(user.login("gosha@roskino.org", "qwerty"))
# # True
# user.update_balance(200)
# user.update_balance(-500)
# print(user.balance)
# # 19700
# Обратите внимание, что от вас требуется только объявить класс. Создавать экземпляров класса не нужно!

# %%
class User:
    def __init__(self, email, password, balance):
        self.email = email
        self.password = password
        if balance:
            self.balance = balance
        else:
            self.balance = 0
        
        
    def login(self, email, password):
        if self.email == email and self.password == password:
            return True
        else:
            return False
    
    def update_balance(self, amount):
        self.balance += amount
    
        
    # def get_email(self):
    #     return self.email
    
    # def get_password_length(self):
    #     return len(self.password)

# Проверка
user = User("gosha@roskino.org", "qwerty", 20_000)
print(user.login("gosha@roskino.org", "qwerty123"))
# False
print(user.login("gosha@roskino.org", "qwerty"))
# True
user.update_balance(200)
user.update_balance(-500)
print(user.balance)
# 19700
# Out:
# False
# True
# 19700

# %% [markdown]
# ### Комбинация операций
#
# Классы могут пригодиться, если вы регулярно делаете над данными одну и ту же последовательность разноплановых функций. Вы можете упаковать их в класс и в дальнейшем сразу получать результат по загруженным данным.
#
# У нас есть численные данные из разных источников. Если они в виде строк, то нужно привести их к числам, а пропуски — заполнить значениями. Сделаем доступ к медиане, среднему значению и стандартному отклонению:

# %%
import statistics  
  
class DataFrame():  
    def __init__(self, column, fill_value=0):  
        # Инициализируем атрибуты  
        self.column = column  
        self.fill_value = fill_value  
        # Заполним пропуски  
        self.fill_missed()  
        # Конвертируем все элементы в числа  
        self.to_float()  
          
    def fill_missed(self):  
        for i, value in enumerate(self.column):  
            if value is None or value == '':  
                self.column[i] = self.fill_value  
                  
    def to_float(self):  
        self.column = [float(value) for value in self.column]  
      
    def median(self):  
        return statistics.median(self.column)  
      
    def mean(self):  
        return statistics.mean(self.column)  
      
    def deviation(self):  
        return statistics.stdev(self.column)  
      
  
      
# Воспользуемся классом  
df = DataFrame(["1", 17, 4, None, 8])  
  
print(df.column)  
# => [1.0, 17.0, 4.0, 0.0, 8.0]  
print(df.deviation())  
# => 6.89  
print(df.median())  
# => 4.0

# %% [markdown]
# Мы получили очень лаконичный интерфейс для использования класса. В __init__ мы использовали значение по умолчанию для fill_value, а методы позволяют нам определять необязательные параметры.

# %% [markdown]
# ### Задание 5.2 (External resource)
# (1.0 points possible)
#
# Определите класс IntDataFrame, который в момент инициализации объектов принимает список неотрицательных чисел и приводит к целым значениям все числа в этом списке, отрезая дробную часть с помощью встроенной функции int().
#
# Результирующий список должен быть сохранен в виде атрибута с именем column.
#
# Также класс должен содержать следующие методы:
#
# count(), который возвращает количество ненулевых элементов в списке column;
#
# unique(), который возвращает число уникальных элементов в списке в списке column.
#
# В случае правильного описания класса код, приведённый ниже, должен выдать следующий результат:
#
# Пример использования класса:
#
#
# df = IntDataFrame([4.7, 4, 3, 0, 2.4, 0.3, 4])
#
# print(df.column)
# ###### [4, 4, 3, 0, 2, 0, 4]
#
# print(df.count())
# ###### 5
#
# print(df.unique())
# ###### 4
# Обратите внимание, что от вас требуется только объявить класс. Создавать экземпляров класса не нужно!

# %%
class IntDataFrame():
    def __init__(self, column, fill_value=0):  
        # Инициализируем атрибуты  
        self.column = column  
        self.fill_value = fill_value  
        # Конвертируем все элементы в числа  
        self.to_int()  
    
    def to_int(self):  
        self.column = [int(value) for value in self.column]
          
    def count(self):
        filtered_numbers = [num for num in self.column if num != 0]
        return len(filtered_numbers)
    
    def unique(self):  
        return len(set(self.column))
    



# Пример использования класса:


df = IntDataFrame([4.7, 4, 3, 0, 2.4, 0.3, 4])

print(df.column)
# [4, 4, 3, 0, 2, 0, 4]

print(df.count())
# 5

print(df.unique())
# 4
# Out:
# [4, 4, 3, 0, 2, 0, 4]
# 5
# 4

# %% [markdown]
# ### Класс-обёртка
#
# Классы можно использовать тогда, когда у вас есть процесс, который требует сложной конфигурации, повторяющейся из раза в раз. Можно написать класс-обёртку, который сведёт этот процесс к одному-двум методам.
#
# Представим, вы делаете обработку данных и в конце каждого дня сохраняете результат в архив. Вы хотите, чтобы данные каждого дня лежали в отдельном файле для этого дня, при этом можно было бы получить данные за произвольный день.
#
# Перед запуском кода создайте папку с названием archive там же, где находится ноутбук:

# %%
import pickle  
from datetime import datetime  
from os import path, makedirs  
  
class Dumper():  
    def __init__(self, archive_dir="archive/"):  
        self.archive_dir = archive_dir  
          
    def dump(self, data):  
        # Создаем директорию, если она не существует
        if not path.exists(self.archive_dir):
            makedirs(self.archive_dir)
        # Библиотека pickle позволяет доставать и класть объекты в файл  
        with open(self.get_file_name(), 'wb') as file:  
            pickle.dump(data, file)  
              
    def load_for_day(self, day):  
        file_name = path.join(self.archive_dir, day + ".pkl")   
        with open(file_name, 'rb') as file:  
            sets = pickle.load(file)  
        return sets  
          
    # возвращает корректное имя для файла   
    def get_file_name(self):   
        today = datetime.now().strftime("%y-%m-%d")   
        return path.join(self.archive_dir, today + ".pkl")  
      
      
# Пример использования  
  
data = {  
    'perfomance': [10, 20, 10],  
    'clients': {"Romashka": 10, "Vector": 34}  
}  
  
  
dumper = Dumper()  
  
# Сохраним данные  
dumper.dump(data)  
  
# Восстановим для сегодняшней даты  
file_name = datetime.now().strftime("%y-%m-%d")
restored_data = dumper.load_for_day(file_name)
print(restored_data)  
# => {'perfomance': [10, 20, 10], 'clients': {'Romashka': 10, 'Vector': 34}}
# Out:
# {'perfomance': [10, 20, 10], 'clients': {'Romashka': 10, 'Vector': 34}}

# %% [markdown]
# Сохранение и восстановление работает в пару строк. В результате мы можем приводить достаточно сложные операции к простому виду.

# %% [markdown]
# ### Задание 5.3 (External resource)
# (1.0 points possible)
#
# Напишите класс сборщика технических сообщений OwnLogger.
#
# У него должен быть
#
# атрибут logs, содержащий {"info": None, "warning": None, "error": None, "all": None}.
#
# метод log(message, level), который записывает сообщения. Здесь сообщение message может быть любым, а level — один из "info", "warning", "error".
#
# метод show_last(level), где level может быть "info", "warning", "error", "all".
#
# Для "all" он просто возвращает последнее добавленное сообщение, а для остальных — последнее поступившее сообщение соответствующего уровня. При этом по умолчанию значение именно "all".
#
# Если подходящего сообщения нет, возвращает None.
#
# В случае правильного описания класса код, приведённый ниже, должен выдать следующий результат:
#
#
#
# logger = OwnLogger()
# logger.log("System started", "info")
# logger.show_last("error")
# # None
# # Некоторые интерпретаторы Python могут не выводить None, тогда в этой проверке у вас будет пустая строка
# logger.log("Connection instable", "warning")
# logger.log("Connection lost", "error")
#
# logger.show_last()
# # Connection lost
# logger.show_last("info")
# # System started

# %%
class OwnLogger:
    def __init__(self):
        self.logs = {"info": None, "warning": None, "error": None, "all": None}
        self.all_logs = []

    def log(self, message, level):
        if level in self.logs:
            self.logs[level] = message
            self.all_logs.append((message, level))
        self.logs["all"] = message

    def show_last(self, level="all"):
        if level == "all":
            return self.logs["all"]
        elif level in self.logs:
            for msg, lvl in reversed(self.all_logs):
                if lvl == level:
                    return msg
        return None
    
### Пример использования:
logger = OwnLogger()
logger.log("System started", "info")
print(logger.show_last("error"))
# None
# Некоторые интерпретаторы Python могут не выводить None, тогда в этой проверке у вас будет пустая строка

logger.log("Connection instable", "warning")
logger.log("Connection lost", "error")

print(logger.show_last())
# Connection lost
print(logger.show_last("info"))
# System started


# logger = OwnLogger()
# logger.log("System started", "info")
# logger.log("Low disk space", "warning")
# logger.log("File not found", "error")

# print(logger.show_last("info"))    # Вывод: System started
# print(logger.show_last("warning")) # Вывод: Low disk space
# print(logger.show_last("error"))   # Вывод: File not found
# print(logger.show_last("all"))     # Вывод: File not found
# Out:
# None
# Connection lost
# System started

# %% [markdown]
# ### Импорт и организация кода
#
# Классы, как и библиотечные функции, можно импортировать в другие программы. Для этого нужно положить класс в отдельный файл в корне проекта и использовать ключевое слово import.
#
# Например, если мы положим Dumper в файл dumper.py в корне проекта, то его можно импортировать командой:

# %%
from helpers.dumper import Dumper  
from helpers.data_frame import DataFrame  
from helpers.client import Client

# %% [markdown]
# ## 6. Проверка знаний

# %% [markdown]
# ### Задание 6.3 (External resource)
#
# Определите класс Dog, у которого есть методы bark и give_paw. При этом, пусть методы принимают список из любого количества аргументов.
#
# bark возвращает строку "Bark!"
# give_paw возвращает строку "Paw"

# %%
class Dog():
    def __init__(self):
        pass

    def bark(self, list):
        return "Bark!"

    def give_paw(self, list):
        return "Paw"

# %% [markdown]
# ## 7. Применение ООП для работы с файлами

# %% [markdown]
#  В этом юните мы с вами поговорим об основных принципах работы с файлами в языке Python — какие встроенные методы используются для открытия, закрытия, чтения, построчного чтения и так далее.
#
# На самом деле файлы, как и всё в Python, являются объектами класса. Причём этот класс встроен в Python. У файлов есть свои атрибуты и методы.
#
# Давайте на примере работы с файлами разберём, как работают классы, реализованные «под капотом» в Python ↓

# %% [markdown]
# ### Путь к файлу
#
# Путь (от англ. path) — набор символов, показывающий расположение файла или каталога в файловой системе.
#
# В операционных системах UNIX разделительным знаком при записи пути является «/» (слеш), в Windows — «\» (обратный слеш). Эти знаки служат для разделения названия каталогов, составляющих путь к файлу. Все вы видели, например, такой путь на ОС Windows: C:\Program Files. Это и есть путь до папки Program Files.
#
# Существует два типа пути:
#
# абсолютный;
# относительный.
# Абсолютный путь всегда считается от «корня», той папки, откуда потом «вырастают» все остальные папки. Для Windows это диск С:, D: и т. д., для Unix это “/”. Абсолютный путь всегда уникальный.
#
# Абсолютный путь — это путь, который указывает на одно и то же место в файловой системе, вне зависимости от текущего рабочего каталога или других обстоятельств. Его ещё называют полным.
#
# Относительный путь — это путь по отношению к текущему рабочему каталогу пользователя.
#
# Чтобы поработать с путями, есть модуль os. Функция os.chdir() позволяет нам изменить директорию, которую мы в данный момент используем. Если вам нужно знать, какой путь вы в данный момент используете, для этого нужно вызвать os.getcwd().
#
# Примечание: Все дальнейшие пути указаны для конкретной машины на ОС Linux. У вас эти результаты будут отличаться.

# %%
import os
# получить текущий путь
start_path = os.getcwd()
print(start_path) # /home/nbuser/library
# Out:
# c:\Users\stepu\OneDrive\IDE\skillfactory\PYTHON-15. Принципы ООП в Python и отладка кода

# %% [markdown]
# Далее попробуем подняться на директорию выше:

# %%
os.chdir("..") # подняться на один уровень выше
os.getcwd() # '/home/nbuser'
# Out:
# 'c:\\Users\\stepu\\OneDrive\\IDE\\skillfactory'

# %% [markdown]
# Теперь вернемся в ту директорию, из которой стартовали. Изначально мы сохраняли её в переменной start_path.

# %%
os.chdir(start_path)
os.getcwd() # '/home/nbuser/library'
# Out:
# 'c:\\Users\\stepu\\OneDrive\\IDE\\skillfactory\\PYTHON-15. Принципы ООП в Python и отладка кода'

# %% [markdown]
# С помощью функции os.listdir() можно получить весь список файлов, находящихся в директории. Если не указать никаких аргументов, то будет взята текущая директория.

# %%
# список файлов и директорий в папке
import os

print(os.listdir()) # ['SnapchatLoader', 'FBLoader', 'tmp.py', '.gitignore', 'venv', '.git']

if 'tmp.py' not in os.listdir():
    print("Файл отсутствует в данной директории")
# Out:
# ['archive', 'data', 'DS_15_theory.ipynb', 'DS_15_work.ipynb', 'helpers', '__pycache__']
# Файл отсутствует в данной директории

# %% [markdown]
# Для того чтобы склеивать пути с учётом особенностей ОС, следует использовать функцию os.path.join(). Это связано с тем, что в разных операционных системах могут быть разные разделители каталогов, например в ОС Windows этим разделителем является «\», а в Linux — «/», как мы и говорили в начале юнита. Поэтому, чтобы поиск файла проходил гладко в обеих системах (ведь ваш скрипт могут запускать на любой системе в связи с кросс-платформенностью Python), лучше всё-таки использовать os.path.join().

# %%
# соединяет пути с учётом особенностей операционной системы
print(start_path)
print(os.path.join(start_path, 'test'))

# /home/nbuser/library
# /home/nbuser/library/test
# Out:
# c:\Users\stepu\OneDrive\IDE\skillfactory\PYTHON-15. Принципы ООП в Python и отладка кода
# c:\Users\stepu\OneDrive\IDE\skillfactory\PYTHON-15. Принципы ООП в Python и отладка кода\test

# %% [markdown]
# ### Задание 7.3
# Задание на самопроверку.
#
# Сделайте функцию, которая принимает от пользователя путь и выводит всю информацию о содержимом этой папки. Для реализации используйте функцию встроенного модуля os.walk(). Если путь не указан, то сравнение начинается с текущей директории.

# %%
import os

def list_directory_contents(path='.'):
    for root, dirs, files in os.walk(path):
        print(f'Корневая директория: {root}')
        if dirs:
            print('Поддиректории:')
            for dir_name in dirs:
                print(f'  {dir_name}')
        else:
            print('Поддиректорий нет')
        if files:
            print('Файлы:')
            for file_name in files:
                print(f'  {file_name}')
        else:
            print('Файлов нет')
        print('-' * 40)

# Пример использования:
user_path = input("Введите путь к директории (или оставьте пустым для текущей директории): ")
if not user_path:
    user_path = '.'

list_directory_contents(user_path)
# Out:
# Корневая директория: D:\
# Поддиректории:
#   $RECYCLE.BIN
#   Dup_Same_Files_Searcher_(2_2_6)
#   LenovoDrivers
#   Program Files (x86)
#   System Volume Information
#   U393
# Файлы:
#   1Cv8_263600786875_202401121850.dt
#   1r9062u1_DUMP_1С_Бухгалтерия_8_КОРП___ИП_20241205_1233.dt
#   Win11_24H2_English_x64.iso
# ----------------------------------------
# Корневая директория: D:\$RECYCLE.BIN
# Поддиректории:
#   S-1-5-21-1206919825-79505992-1108725795-1001
#   S-1-5-21-3084477054-1813227533-2620967763-1001
# Файлов нет
# ----------------------------------------
# Корневая директория: D:\$RECYCLE.BIN\S-1-5-21-3084477054-1813227533-2620967763-1001
# Поддиректорий нет
# Файлы:
#   desktop.ini
# ----------------------------------------
# Корневая директория: D:\Dup_Same_Files_Searcher_(2_2_6)
# Поддиректории:
#   Language
# Файлы:
#   DuplicateSearcher.exe
#   DuplicateSearcher.exe.config
#   DuplicateSearcher.exe.manifest
#   History.txt
#   History_ru.txt
#   Ionic.Zip.Reduced.dll
#   License.txt
#   Non commertial use.key
#   README.rus.txt
#   README.txt
# ----------------------------------------
# Корневая директория: D:\Dup_Same_Files_Searcher_(2_2_6)\Language
# Поддиректорий нет
# Файлы:
#   Add new languages here
#   English (example).txt
#   French.lng
#   Italiano.lng
#   Japanese.lng
#   Polish.lng
#   Russian.lng
# ----------------------------------------
# Корневая директория: D:\LenovoDrivers
# Поддиректории:
#   LenovoThinkbook16G6+IMH
#   LenovoThinkbook16G6+IMH 20241216
# Файлов нет
# ----------------------------------------
# Корневая директория: D:\LenovoDrivers\LenovoThinkbook16G6+IMH
# Поддиректории:
#   App
#   Audio
#   BIOS
#   Bluetooth
#   Camera
#   Cardreader
#   Drivers from Saler
#   Fingerprint
#   HotKey
#   Intel dynamic technology
#   Intel managment engine
#   LAN
#   Motherboard
#   Power
#   ThinkVantage
#   USB HID
#   Videocard
#   WLAN
# Файлы:
#   ldiag_5.14.2_windows_x64.exe
#   Lenovo PSREF for Windows Installer.exe
#   Lenovo Vantage Installer.exe
#   LenovoDM_Setup.exe
#   newthink.lenovo.com.cn.url
# ----------------------------------------
# Корневая директория: D:\LenovoDrivers\LenovoThinkbook16G6+IMH\App
# Поддиректорий нет
# Файлы:
#   Dispatcher-RID30A0FD2WJ5JF0.exe
#   GFE-QPTG037FP1CXVPF0.exe
# ----------------------------------------
# Корневая директория: D:\LenovoDrivers\LenovoThinkbook16G6+IMH\Audio
# Поддиректорий нет
# Файлы:
#   Audio-QPTG027FQP93GPF0.exe
# ----------------------------------------
# Корневая директория: D:\LenovoDrivers\LenovoThinkbook16G6+IMH\BIOS
# Поддиректорий нет
# Файлы:
#   BIOS-NJCN50WW.exe
# ----------------------------------------
# Корневая директория: D:\LenovoDrivers\LenovoThinkbook16G6+IMH\Bluetooth
# Поддиректорий нет
# Файлы:
#   IntelBT-QPTG037FH42A9PF0.exe
# ----------------------------------------
# Корневая директория: D:\LenovoDrivers\LenovoThinkbook16G6+IMH\Camera
# Поддиректорий нет
# Файлы:
#   Camera-QPTG017FEAD6TPF0.exe
# ----------------------------------------
# Корневая директория: D:\LenovoDrivers\LenovoThinkbook16G6+IMH\Cardreader
# Поддиректорий нет
# Файлы:
#   CardReader-QPTG017F8D7MBPF0.exe
# ----------------------------------------
# Корневая директория: D:\LenovoDrivers\LenovoThinkbook16G6+IMH\Drivers from Saler
# Поддиректории:
#   Audio
#   Bluetooth
#   Camera
#   Cardreader
#   Chipset
#   CursorSpeed
#   DolbyUI
#   DTT
#   FingerPrint
#   HID
#   IGCC
#   IntelGNA
#   IntelVGA
#   LAN
#   LNVDispatcherService
#   MEI
#   NPU
#   NVDIA_CPL
#   NVDIA_GFE
#   NVDIA_VGA
#   PMT
#   PPM
#   Sensor
#   SerialIO
#   Tcon
#   WLAN
#   ZeroTouchDriver
# Файлов нет
# ----------------------------------------
# Корневая директория: D:\LenovoDrivers\LenovoThinkbook16G6+IMH\Drivers from Saler\Audio
# Поддиректории:
#   3rd party
#   ExtRtk_IntcOED
#   Realtek
#   SST9870
# Файлы:
#   InstallPackage.bat
# ----------------------------------------
# Корневая директория: D:\LenovoDrivers\LenovoThinkbook16G6+IMH\Drivers from Saler\Audio\3rd party
# Поддиректории:
#   Dolby
#   Elevoc
# Файлов нет
# ----------------------------------------
# Корневая директория: D:\LenovoDrivers\LenovoThinkbook16G6+IMH\Drivers from Saler\Audio\3rd party\Dolby
# Поддиректории:
#   ext_lenovo_AIO_rtk_21h2_22h2_v8.1027.251.1
#   swc_factory_3.6
# Файлов нет
# ----------------------------------------
# Корневая директория: D:\LenovoDrivers\LenovoThinkbook16G6+IMH\Drivers from Saler\Audio\3rd party\Dolby\ext_lenovo_AIO_rtk_21h2_22h2_v8.1027.251.1
# Поддиректорий нет
# Файлы:
#   dax3_ext_rtk.cat
#   dax3_ext_rtk.inf
#   DEV_0230_SUBSYS_17AA3839_PCI_SUBSYS_381817AA.xml
#   DEV_0230_SUBSYS_17AA3839_PCI_SUBSYS_381817AA_settings.xml
#   DEV_0230_SUBSYS_17AA383A_PCI_SUBSYS_381817AA.xml
#   DEV_0230_SUBSYS_17AA383A_PCI_SUBSYS_381817AA_settings.xml
#   DEV_0230_SUBSYS_17AA383B_PCI_SUBSYS_381817AA.xml
#   DEV_0230_SUBSYS_17AA383C_PCI_SUBSYS_382217AA.xml
#   DEV_0230_SUBSYS_17AA383C_PCI_SUBSYS_382217AA_settings.xml
#   DEV_0230_SUBSYS_17AA383D_PCI_SUBSYS_382217AA.xml
#   DEV_0230_SUBSYS_17AA383D_PCI_SUBSYS_382217AA_settings.xml
#   DEV_0230_SUBSYS_17AA383E_PCI_SUBSYS_382217AA.xml
#   DEV_0230_SUBSYS_17AA383F_PCI_SUBSYS_380917AA.xml
#   DEV_0230_SUBSYS_17AA383F_PCI_SUBSYS_380917AA_settings.xml
#   DEV_0230_SUBSYS_17AA3840_PCI_SUBSYS_380917AA.xml
#   DEV_0230_SUBSYS_17AA3840_PCI_SUBSYS_380917AA_settings.xml
#   DEV_0230_SUBSYS_17AA3841_PCI_SUBSYS_380917AA.xml
#   DEV_0230_SUBSYS_17AA3845_PCI_SUBSYS_383F17AA.xml
#   DEV_0230_SUBSYS_17AA3845_PCI_SUBSYS_383F17AA_settings.xml
#   DEV_0230_SUBSYS_17AA3847_PCI_SUBSYS_383F17AA.xml
#   DEV_0230_SUBSYS_17AA3847_PCI_SUBSYS_383F17AA_settings.xml
#   DEV_0230_SUBSYS_17AA3849_PCI_SUBSYS_381017AA.xml
#   DEV_0230_SUBSYS_17AA3849_PCI_SUBSYS_381017AA_settings.xml
#   DEV_0230_SUBSYS_17AA384A_PCI_SUBSYS_381017AA.xml
#   DEV_0230_SUBSYS_17AA384A_PCI_SUBSYS_381017AA_settings.xml
#   DEV_0230_SUBSYS_17AA3852_PCI_SUBSYS_383A17AA.xml
#   DEV_0230_SUBSYS_17AA3853_PCI_SUBSYS_383F17AA.xml
#   DEV_0230_SUBSYS_17AA3855_PCI_SUBSYS_382D17AA.xml
#   DEV_0230_SUBSYS_17AA3855_PCI_SUBSYS_382D17AA_settings.xml
#   DEV_0230_SUBSYS_17AA3856_PCI_SUBSYS_383A17AA.xml
#   DEV_0230_SUBSYS_17AA3857_PCI_SUBSYS_383A17AA.xml
#   DEV_0230_SUBSYS_17AA3858_PCI_SUBSYS_382D17AA.xml
#   DEV_0230_SUBSYS_17AA3858_PCI_SUBSYS_382D17AA_settings.xml
#   DEV_0235_SUBSYS_17AA3173_PCI_SUBSYS_317317AA.xml
#   DEV_0235_SUBSYS_17AA3174_PCI_SUBSYS_317417AA.xml
#   DEV_0235_SUBSYS_17AA3179_PCI_SUBSYS_317917AA.xml
#   DEV_0235_SUBSYS_17AA3193_PCI_SUBSYS_319317AA.xml
#   DEV_0235_SUBSYS_17AA3194_PCI_SUBSYS_319417AA.xml
#   DEV_0235_SUBSYS_17AA31B5_PCI_SUBSYS_31B517AA.xml
#   DEV_0235_SUBSYS_17AA31B8_PCI_SUBSYS_31B817AA.xml
#   DEV_0235_SUBSYS_17AA31B9_PCI_SUBSYS_31B917AA.xml
#   DEV_0235_SUBSYS_17AA31BA_PCI_SUBSYS_31BA17AA.xml
#   DEV_0235_SUBSYS_17AA31BC_PCI_SUBSYS_31BC17AA.xml
#   DEV_0235_SUBSYS_17AA31C2_PCI_SUBSYS_31C217AA.xml
#   DEV_0235_SUBSYS_17AA32C1_PCI_SUBSYS_32C117AA.xml
#   DEV_0235_SUBSYS_17AA32C6_PCI_SUBSYS_32C617AA.xml
#   DEV_0235_SUBSYS_17AA334F_PCI_SUBSYS_334F17AA.xml
#   DEV_0235_SUBSYS_17AA371B_PCI_SUBSYS_371B17AA.xml
#   DEV_0235_SUBSYS_17AA371C_PCI_SUBSYS_371C17AA.xml
#   DEV_0235_SUBSYS_17AA371D_PCI_SUBSYS_371D17AA.xml
#   DEV_0235_SUBSYS_17AA3721_PCI_SUBSYS_372117AA.xml
#   DEV_0235_SUBSYS_17AA3722_PCI_SUBSYS_372217AA.xml
#   DEV_0235_SUBSYS_17AA3725_PCI_SUBSYS_371B17AA.xml
#   DEV_0235_SUBSYS_17AA3726_PCI_SUBSYS_372117AA.xml
#   DEV_0235_SUBSYS_17AA372E_PCI_SUBSYS_371C17AA.xml
#   DEV_0235_SUBSYS_17AA372F_PCI_SUBSYS_371D17AA.xml
#   DEV_0235_SUBSYS_17AA3735_PCI_SUBSYS_373717AA.xml
#   DEV_0235_SUBSYS_17AA3736_PCI_SUBSYS_373817AA.xml
#   DEV_0235_SUBSYS_17AA3737_PCI_SUBSYS_373717AA.xml
#   DEV_0235_SUBSYS_17AA3738_PCI_SUBSYS_373817AA.xml
#   DEV_0235_SUBSYS_17AA373C_PCI_SUBSYS_374717AA.xml
#   DEV_0235_SUBSYS_17AA373D_PCI_SUBSYS_374417AA.xml
#   DEV_0235_SUBSYS_17AA373E_PCI_SUBSYS_374C17AA.xml
#   DEV_0235_SUBSYS_17AA3744_PCI_SUBSYS_374417AA.xml
#   DEV_0235_SUBSYS_17AA3744_PCI_SUBSYS_377617AA.xml
#   DEV_0235_SUBSYS_17AA3745_PCI_SUBSYS_374617AA.xml
#   DEV_0235_SUBSYS_17AA3746_PCI_SUBSYS_374617AA.xml
#   DEV_0235_SUBSYS_17AA3746_PCI_SUBSYS_377717AA.xml
#   DEV_0235_SUBSYS_17AA3747_PCI_SUBSYS_374717AA.xml
#   DEV_0235_SUBSYS_17AA3748_PCI_SUBSYS_374917AA.xml
#   DEV_0235_SUBSYS_17AA3749_PCI_SUBSYS_374917AA.xml
#   DEV_0235_SUBSYS_17AA374A_PCI_SUBSYS_374B17AA.xml
#   DEV_0235_SUBSYS_17AA374B_PCI_SUBSYS_374B17AA.xml
#   DEV_0235_SUBSYS_17AA374C_PCI_SUBSYS_374C17AA.xml
#   DEV_0235_SUBSYS_17AA374D_PCI_SUBSYS_374E17AA.xml
#   DEV_0235_SUBSYS_17AA374E_PCI_SUBSYS_374E17AA.xml
#   DEV_0235_SUBSYS_17AA376B_PCI_SUBSYS_376B17AA.xml
#   DEV_0235_SUBSYS_17AA3780_PCI_SUBSYS_378017AA.xml
#   DEV_0235_SUBSYS_17AA3781_PCI_SUBSYS_378117AA.xml
#   DEV_0235_SUBSYS_17AA3782_PCI_SUBSYS_378217AA.xml
#   DEV_0235_SUBSYS_17AA3783_PCI_SUBSYS_378317AA.xml
#   DEV_0256_SUBSYS_17AA32F3_PCI_SUBSYS_32F317AA.xml
#   DEV_0256_SUBSYS_17AA32F5_PCI_SUBSYS_32F517AA.xml
#   DEV_0256_SUBSYS_17AA3305_PCI_SUBSYS_330517AA.xml
#   DEV_0256_SUBSYS_17AA3306_PCI_SUBSYS_330617AA.xml
#   DEV_0256_SUBSYS_17AA330F_PCI_SUBSYS_330F17AA.xml
#   DEV_0256_SUBSYS_17AA3345_PCI_SUBSYS_334517AA.xml
#   DEV_0256_SUBSYS_17AA373D_PCI_SUBSYS_374417AA.xml
#   DEV_0256_SUBSYS_17AA3744_PCI_SUBSYS_374417AA.xml
#   DEV_0256_SUBSYS_17AA3745_PCI_SUBSYS_374617AA.xml
#   DEV_0256_SUBSYS_17AA3746_PCI_SUBSYS_374617AA.xml
#   DEV_0256_SUBSYS_17AA3758_PCI_SUBSYS_375817AA.xml
#   DEV_0256_SUBSYS_17AA3759_PCI_SUBSYS_375817AA.xml
#   DEV_0256_SUBSYS_17AA375A_PCI_SUBSYS_375A17AA.xml
#   DEV_0256_SUBSYS_17AA375B_PCI_SUBSYS_375A17AA.xml
#   DEV_0256_SUBSYS_17AA375C_PCI_SUBSYS_375C17AA.xml
#   DEV_0256_SUBSYS_17AA375D_PCI_SUBSYS_375C17AA.xml
#   DEV_0256_SUBSYS_17AA3773_PCI_SUBSYS_377317AA.xml
#   DEV_0256_SUBSYS_17AA3774_PCI_SUBSYS_377417AA.xml
#   DEV_0256_SUBSYS_17AA3775_PCI_SUBSYS_377517AA.xml
#   DEV_0256_SUBSYS_17AA3780_PCI_SUBSYS_378017AA.xml
#   DEV_0256_SUBSYS_17AA3781_PCI_SUBSYS_378117AA.xml
#   DEV_0256_SUBSYS_17AA3782_PCI_SUBSYS_378217AA.xml
#   DEV_0256_SUBSYS_17AA3783_PCI_SUBSYS_378317AA.xml
#   DEV_0257_SUBSYS_17AA22F0_PCI_SUBSYS_22F017AA.xml
#   DEV_0257_SUBSYS_17AA3827_PCI_SUBSYS_383F17AA.xml
#   DEV_0257_SUBSYS_17AA3827_PCI_SUBSYS_383F17AA_settings.xml
#   DEV_0257_SUBSYS_17AA382F_PCI_SUBSYS_382F17AA.xml
#   DEV_0257_SUBSYS_17AA3830_PCI_SUBSYS_380F17AA.xml
#   DEV_0257_SUBSYS_17AA3832_PCI_SUBSYS_383217AA.xml
#   DEV_0257_SUBSYS_17AA3841_PCI_SUBSYS_381617AA.xml
#   DEV_0257_SUBSYS_17AA3842_PCI_SUBSYS_381617AA.xml
#   DEV_0257_SUBSYS_17AA384C_PCI_SUBSYS_381617AA.xml
#   DEV_0257_SUBSYS_17AA3851_PCI_SUBSYS_385217AA.xml
#   DEV_0257_SUBSYS_17AA3852_PCI_SUBSYS_385217AA.xml
#   DEV_0257_SUBSYS_17AA385B_PCI_SUBSYS_384117AA.xml
#   DEV_0257_SUBSYS_17AA385B_PCI_SUBSYS_384117AA_settings.xml
#   DEV_0257_SUBSYS_17AA3860_PCI_SUBSYS_382117AA.xml
#   DEV_0257_SUBSYS_17AA3861_PCI_SUBSYS_382117AA.xml
#   DEV_0257_SUBSYS_17AA3862_PCI_SUBSYS_382117AA.xml
#   DEV_0257_SUBSYS_17AA3863_PCI_SUBSYS_382117AA.xml
#   DEV_0257_SUBSYS_17AA3864_PCI_SUBSYS_382317AA.xml
#   DEV_0257_SUBSYS_17AA3864_PCI_SUBSYS_382317AA_settings.xml
#   DEV_0257_SUBSYS_17AA3865_PCI_SUBSYS_382317AA.xml
#   DEV_0257_SUBSYS_17AA3865_PCI_SUBSYS_382317AA_settings.xml
#   DEV_0257_SUBSYS_17AA3866_PCI_SUBSYS_386617AA.xml
#   DEV_0257_SUBSYS_17AA3869_PCI_SUBSYS_382017AA.xml
#   DEV_0257_SUBSYS_17AA3869_PCI_SUBSYS_382017AA_settings.xml
#   DEV_0257_SUBSYS_17AA386C_PCI_SUBSYS_382317AA.xml
#   DEV_0257_SUBSYS_17AA386C_PCI_SUBSYS_382317AA_settings.xml
#   DEV_0257_SUBSYS_17AA386D_PCI_SUBSYS_381C17AA.xml
#   DEV_0257_SUBSYS_17AA3870_PCI_SUBSYS_381117AA.xml
#   DEV_0257_SUBSYS_17AA3871_PCI_SUBSYS_381117AA.xml
#   DEV_0257_SUBSYS_17AA3872_PCI_SUBSYS_380F17AA.xml
#   DEV_0257_SUBSYS_17AA3873_PCI_SUBSYS_380F17AA.xml
#   DEV_0257_SUBSYS_17AA3874_PCI_SUBSYS_380E17AA.xml
#   DEV_0257_SUBSYS_17AA3875_PCI_SUBSYS_380F17AA.xml
#   DEV_0257_SUBSYS_17AA387A_PCI_SUBSYS_381117AA.xml
#   DEV_0257_SUBSYS_17AA387B_PCI_SUBSYS_380517AA.xml
#   DEV_0257_SUBSYS_17AA387C_PCI_SUBSYS_380517AA.xml
#   DEV_0257_SUBSYS_17AA387D_PCI_SUBSYS_381B17AA.xml
#   DEV_0257_SUBSYS_17AA387F_PCI_SUBSYS_381F17AA.xml
#   DEV_0257_SUBSYS_17AA387F_PCI_SUBSYS_381F17AA_settings.xml
#   DEV_0257_SUBSYS_17AA3883_PCI_SUBSYS_380D17AA.xml
#   DEV_0257_SUBSYS_17AA3885_PCI_SUBSYS_380417AA.xml
#   DEV_0257_SUBSYS_17AA3886_PCI_SUBSYS_380317AA.xml
#   DEV_0257_SUBSYS_17AA3887_PCI_SUBSYS_382517AA.xml
#   DEV_0257_SUBSYS_17AA3889_PCI_SUBSYS_381C17AA.xml
#   DEV_0257_SUBSYS_17AA388A_PCI_SUBSYS_380217AA.xml
#   DEV_0257_SUBSYS_17AA388D_PCI_SUBSYS_381017AA.xml
#   DEV_0257_SUBSYS_17AA388E_PCI_SUBSYS_381017AA.xml
#   DEV_0257_SUBSYS_17AA3891_PCI_SUBSYS_381017AA.xml
#   DEV_0257_SUBSYS_17AA3892_PCI_SUBSYS_381017AA.xml
#   DEV_0257_SUBSYS_17AA3893_PCI_SUBSYS_381017AA.xml
#   DEV_0257_SUBSYS_17AA3893_PCI_SUBSYS_381017AA_settings.xml
#   DEV_0257_SUBSYS_17AA3894_PCI_SUBSYS_381D17AA.xml
#   DEV_0257_SUBSYS_17AA3894_PCI_SUBSYS_381D17AA_settings.xml
#   DEV_0257_SUBSYS_17AA3897_PCI_SUBSYS_381B17AA.xml
#   DEV_0257_SUBSYS_17AA3899_PCI_SUBSYS_380417AA.xml
#   DEV_0257_SUBSYS_17AA389A_PCI_SUBSYS_380317AA.xml
#   DEV_0257_SUBSYS_17AA389B_PCI_SUBSYS_380317AA.xml
#   DEV_0257_SUBSYS_17AA389C_PCI_SUBSYS_382417AA.xml
#   DEV_0257_SUBSYS_17AA389D_PCI_SUBSYS_382417AA.xml
#   DEV_0257_SUBSYS_17AA389E_PCI_SUBSYS_382417AA.xml
#   DEV_0257_SUBSYS_17AA38A1_PCI_SUBSYS_382D17AA.xml
#   DEV_0257_SUBSYS_17AA38A2_PCI_SUBSYS_382D17AA.xml
#   DEV_0257_SUBSYS_17AA38A3_PCI_SUBSYS_380717AA.xml
#   DEV_0257_SUBSYS_17AA38A4_PCI_SUBSYS_380717AA.xml
#   DEV_0257_SUBSYS_17AA38A6_PCI_SUBSYS_381017AA.xml
#   DEV_0257_SUBSYS_17AA38A6_PCI_SUBSYS_381017AA_settings.xml
#   DEV_0257_SUBSYS_17AA38AD_PCI_SUBSYS_380617AA.xml
#   DEV_0257_SUBSYS_17AA38B0_PCI_SUBSYS_381917AA.xml
#   DEV_0257_SUBSYS_17AA38B0_PCI_SUBSYS_381917AA_settings.xml
#   DEV_0257_SUBSYS_17AA38B3_PCI_SUBSYS_382817AA.xml
#   DEV_0257_SUBSYS_17AA38B3_PCI_SUBSYS_382817AA_settings.xml
#   DEV_0257_SUBSYS_17AA38B4_PCI_SUBSYS_380E17AA.xml
#   DEV_0257_SUBSYS_17AA38B5_PCI_SUBSYS_380E17AA.xml
#   DEV_0257_SUBSYS_17AA38B6_PCI_SUBSYS_380E17AA.xml
#   DEV_0257_SUBSYS_17AA38B7_PCI_SUBSYS_380E17AA.xml
#   DEV_0257_SUBSYS_17AA38B8_PCI_SUBSYS_380E17AA.xml
#   DEV_0257_SUBSYS_17AA38B9_PCI_SUBSYS_383717AA.xml
#   DEV_0257_SUBSYS_17AA38BA_PCI_SUBSYS_383717AA.xml
#   DEV_0257_SUBSYS_17AA38BB_PCI_SUBSYS_380517AA.xml
#   DEV_0257_SUBSYS_17AA38BC_PCI_SUBSYS_380517AA.xml
#   DEV_0257_SUBSYS_17AA38BD_PCI_SUBSYS_380517AA.xml
#   DEV_0257_SUBSYS_17AA38BE_PCI_SUBSYS_380517AA.xml
#   DEV_0257_SUBSYS_17AA38BF_PCI_SUBSYS_380517AA.xml
#   DEV_0257_SUBSYS_17AA38C0_PCI_SUBSYS_382917AA.xml
#   DEV_0257_SUBSYS_17AA38C1_PCI_SUBSYS_382917AA.xml
#   DEV_0257_SUBSYS_17AA38C4_PCI_SUBSYS_382C17AA.xml
#   DEV_0257_SUBSYS_17AA38C5_PCI_SUBSYS_382C17AA.xml
#   DEV_0257_SUBSYS_17AA38C8_PCI_SUBSYS_382C17AA.xml
#   DEV_0257_SUBSYS_17AA38C9_PCI_SUBSYS_382C17AA.xml
#   DEV_0257_SUBSYS_17AA38CA_PCI_SUBSYS_382A17AA.xml
#   DEV_0257_SUBSYS_17AA38CB_PCI_SUBSYS_383317AA.xml
#   DEV_0257_SUBSYS_17AA38D5_PCI_SUBSYS_383817AA.xml
#   DEV_0257_SUBSYS_17AA38D5_PCI_SUBSYS_383817AA_settings.xml
#   DEV_0257_SUBSYS_17AA3922_PCI_SUBSYS_381217AA.xml
#   DEV_0257_SUBSYS_17AA3923_PCI_SUBSYS_381217AA.xml
#   DEV_0257_SUBSYS_17AA3924_PCI_SUBSYS_381217AA.xml
#   DEV_0257_SUBSYS_17AA3925_PCI_SUBSYS_383F17AA.xml
#   DEV_0257_SUBSYS_17AA3926_PCI_SUBSYS_383F17AA.xml
#   DEV_0257_SUBSYS_17AA3926_PCI_SUBSYS_383F17AA_settings.xml
#   DEV_0257_SUBSYS_17AA392D_PCI_SUBSYS_380917AA.xml
#   DEV_0257_SUBSYS_17AA392D_PCI_SUBSYS_380917AA_settings.xml
#   DEV_0257_SUBSYS_17AA392E_PCI_SUBSYS_380917AA.xml
#   DEV_0257_SUBSYS_17AA392E_PCI_SUBSYS_380917AA_settings.xml
#   DEV_0257_SUBSYS_17AA392F_PCI_SUBSYS_380917AA.xml
#   DEV_0257_SUBSYS_17AA3932_PCI_SUBSYS_380117AA.xml
#   DEV_0257_SUBSYS_17AA3932_PCI_SUBSYS_380117AA_settings.xml
#   DEV_0257_SUBSYS_17AA3933_PCI_SUBSYS_380117AA.xml
#   DEV_0257_SUBSYS_17AA3933_PCI_SUBSYS_380117AA_settings.xml
#   DEV_0257_SUBSYS_17AA3936_PCI_SUBSYS_383F17AA.xml
#   DEV_0257_SUBSYS_17AA3937_PCI_SUBSYS_383F17AA.xml
#   DEV_0257_SUBSYS_17AA3938_PCI_SUBSYS_383F17AA.xml
#   DEV_0257_SUBSYS_17AA3939_PCI_SUBSYS_380117AA.xml
#   DEV_0257_SUBSYS_17AA393A_PCI_SUBSYS_381017AA.xml
#   DEV_0257_SUBSYS_17AA393A_PCI_SUBSYS_381017AA_settings.xml
#   DEV_0257_SUBSYS_17AA393B_PCI_SUBSYS_381017AA.xml
#   DEV_0257_SUBSYS_17AA393B_PCI_SUBSYS_381017AA_settings.xml
#   DEV_0257_SUBSYS_17AA393E_PCI_SUBSYS_381817AA.xml
#   DEV_0257_SUBSYS_17AA393E_PCI_SUBSYS_381817AA_settings.xml
#   DEV_0257_SUBSYS_17AA393F_PCI_SUBSYS_381817AA.xml
#   DEV_0257_SUBSYS_17AA393F_PCI_SUBSYS_381817AA_settings.xml
#   DEV_0257_SUBSYS_17AA3940_PCI_SUBSYS_381817AA.xml
#   DEV_0257_SUBSYS_17AA3943_PCI_SUBSYS_380817AA.xml
#   DEV_0257_SUBSYS_17AA3944_PCI_SUBSYS_380917AA.xml
#   DEV_0257_SUBSYS_17AA3945_PCI_SUBSYS_380B17AA.xml
#   DEV_0257_SUBSYS_17AA3946_PCI_SUBSYS_380C17AA.xml
#   DEV_0257_SUBSYS_17AA3949_PCI_SUBSYS_384217AA.xml
#   DEV_0257_SUBSYS_17AA3949_PCI_SUBSYS_384217AA_settings.xml
#   DEV_0257_SUBSYS_17AA394A_PCI_SUBSYS_384217AA.xml
#   DEV_0257_SUBSYS_17AA394A_PCI_SUBSYS_384217AA_settings.xml
#   DEV_0257_SUBSYS_17AA3957_PCI_SUBSYS_384317AA.xml
#   DEV_0257_SUBSYS_17AA3958_PCI_SUBSYS_382017AA.xml
#   DEV_0257_SUBSYS_17AA3959_PCI_SUBSYS_382017AA.xml
#   DEV_0257_SUBSYS_17AA395A_PCI_SUBSYS_382017AA.xml
#   DEV_0257_SUBSYS_17AA395B_PCI_SUBSYS_382017AA.xml
#   DEV_0257_SUBSYS_17AA395E_PCI_SUBSYS_384417AA.xml
#   DEV_0257_SUBSYS_17AA3960_PCI_SUBSYS_380617AA.xml
#   DEV_0257_SUBSYS_17AA3963_PCI_SUBSYS_382D17AA.xml
#   DEV_0257_SUBSYS_17AA3963_PCI_SUBSYS_382D17AA_settings.xml
#   DEV_0257_SUBSYS_17AA3964_PCI_SUBSYS_382D17AA.xml
#   DEV_0257_SUBSYS_17AA3964_PCI_SUBSYS_382D17AA_settings.xml
#   DEV_0257_SUBSYS_17AA3966_PCI_SUBSYS_387017AA.xml
#   DEV_0257_SUBSYS_17AA3966_PCI_SUBSYS_387017AA_settings.xml
#   DEV_0257_SUBSYS_17AA3967_PCI_SUBSYS_384517AA.xml
#   DEV_0257_SUBSYS_17AA3967_PCI_SUBSYS_384517AA_settings.xml
#   DEV_0257_SUBSYS_17AA3968_PCI_SUBSYS_387A17AA.xml
#   DEV_0257_SUBSYS_17AA3968_PCI_SUBSYS_387A17AA_settings.xml
#   DEV_0257_SUBSYS_17AA3969_PCI_SUBSYS_384617AA.xml
#   DEV_0257_SUBSYS_17AA396A_PCI_SUBSYS_387B17AA.xml
#   DEV_0257_SUBSYS_17AA396A_PCI_SUBSYS_387B17AA_settings.xml
#   DEV_0257_SUBSYS_17AA396B_PCI_SUBSYS_387C17AA.xml
#   DEV_0257_SUBSYS_17AA396B_PCI_SUBSYS_387C17AA_settings.xml
#   DEV_0257_SUBSYS_17AA396C_PCI_SUBSYS_384717AA.xml
#   DEV_0257_SUBSYS_17AA396C_PCI_SUBSYS_384717AA_settings.xml
#   DEV_0257_SUBSYS_17AA396D_PCI_SUBSYS_384617AA.xml
#   DEV_0257_SUBSYS_17AA396E_PCI_SUBSYS_380617AA.xml
#   DEV_0257_SUBSYS_17AA396F_PCI_SUBSYS_384717AA.xml
#   DEV_0257_SUBSYS_17AA396F_PCI_SUBSYS_384717AA_settings.xml
#   DEV_0257_SUBSYS_17AA3970_PCI_SUBSYS_384817AA.xml
#   DEV_0257_SUBSYS_17AA3970_PCI_SUBSYS_384817AA_settings.xml
#   DEV_0257_SUBSYS_17AA3971_PCI_SUBSYS_384917AA.xml
#   DEV_0257_SUBSYS_17AA3972_PCI_SUBSYS_384A17AA.xml
#   DEV_0257_SUBSYS_17AA3972_PCI_SUBSYS_384A17AA_settings.xml
#   DEV_0257_SUBSYS_17AA3973_PCI_SUBSYS_384A17AA.xml
#   DEV_0257_SUBSYS_17AA3973_PCI_SUBSYS_384A17AA_settings.xml
#   DEV_0257_SUBSYS_17AA3974_PCI_SUBSYS_387D17AA.xml
#   DEV_0257_SUBSYS_17AA3974_PCI_SUBSYS_387D17AA_settings.xml
#   DEV_0257_SUBSYS_17AA3975_PCI_SUBSYS_384B17AA.xml
#   DEV_0257_SUBSYS_17AA3976_PCI_SUBSYS_384C17AA.xml
#   DEV_0257_SUBSYS_17AA3978_PCI_SUBSYS_387E17AA.xml
#   DEV_0257_SUBSYS_17AA397A_PCI_SUBSYS_387F17AA.xml
#   DEV_0257_SUBSYS_17AA397C_PCI_SUBSYS_387F17AA.xml
#   DEV_0257_SUBSYS_17AA397F_PCI_SUBSYS_388117AA.xml
#   DEV_0257_SUBSYS_17AA3980_PCI_SUBSYS_388117AA.xml
#   DEV_0257_SUBSYS_17AA3981_PCI_SUBSYS_388117AA.xml
#   DEV_0257_SUBSYS_17AA3982_PCI_SUBSYS_388117AA.xml
#   DEV_0257_SUBSYS_17AA3983_PCI_SUBSYS_388117AA.xml
#   DEV_0257_SUBSYS_17AA3984_PCI_SUBSYS_388117AA.xml
#   DEV_0257_SUBSYS_17AA3985_PCI_SUBSYS_388217AA.xml
#   DEV_0257_SUBSYS_17AA3986_PCI_SUBSYS_383617AA.xml
#   DEV_0257_SUBSYS_17AA3988_PCI_SUBSYS_384D17AA.xml
#   DEV_0257_SUBSYS_17AA39D4_PCI_SUBSYS_384D17AA.xml
#   DEV_0257_SUBSYS_17AA39D7_PCI_SUBSYS_388417AA.xml
#   DEV_0257_SUBSYS_17AA39D7_PCI_SUBSYS_388417AA_settings.xml
#   DEV_0257_SUBSYS_17AA39D8_PCI_SUBSYS_385117AA.xml
#   DEV_0257_SUBSYS_17AA39D9_PCI_SUBSYS_385117AA.xml
#   DEV_0257_SUBSYS_17AA39DA_PCI_SUBSYS_385117AA.xml
#   DEV_0257_SUBSYS_17AA39DB_PCI_SUBSYS_385117AA.xml
#   DEV_0257_SUBSYS_17AA39DC_PCI_SUBSYS_385117AA.xml
#   DEV_0257_SUBSYS_17AA39DD_PCI_SUBSYS_385117AA.xml
#   DEV_0257_SUBSYS_17AA39DE_PCI_SUBSYS_385117AA.xml
#   DEV_0257_SUBSYS_17AA39DF_PCI_SUBSYS_388D17AA.xml
#   DEV_0257_SUBSYS_17AA39DF_PCI_SUBSYS_388D17AA_settings.xml
#   DEV_0257_SUBSYS_17AA39EA_PCI_SUBSYS_385517AA.xml
#   DEV_0257_SUBSYS_17AA39EB_PCI_SUBSYS_388117AA.xml
#   DEV_0257_SUBSYS_17AA39EC_PCI_SUBSYS_388117AA.xml
#   DEV_0257_SUBSYS_17AA39ED_PCI_SUBSYS_388F17AA.xml
#   DEV_0257_SUBSYS_17AA39EE_PCI_SUBSYS_385617AA.xml
#   DEV_0257_SUBSYS_17AA39EF_PCI_SUBSYS_385817AA.xml
#   DEV_0257_SUBSYS_17AA39F2_PCI_SUBSYS_385917AA.xml
#   DEV_0257_SUBSYS_17AA39F3_PCI_SUBSYS_385B17AA.xml
#   DEV_0257_SUBSYS_17AA39F3_PCI_SUBSYS_385B17AA_settings.xml
#   DEV_0257_SUBSYS_17AA39F4_PCI_SUBSYS_389217AA.xml
#   DEV_0257_SUBSYS_17AA39F4_PCI_SUBSYS_389217AA_settings.xml
#   DEV_0257_SUBSYS_17AA39F5_PCI_SUBSYS_385D17AA.xml
#   DEV_0257_SUBSYS_17AA39F5_PCI_SUBSYS_385D17AA_settings.xml
#   DEV_0257_SUBSYS_17AA39F6_PCI_SUBSYS_385E17AA.xml
#   DEV_0257_SUBSYS_17AA39F7_PCI_SUBSYS_380E17AA.xml
#   DEV_0257_SUBSYS_17AA39F8_PCI_SUBSYS_380E17AA.xml
#   DEV_0257_SUBSYS_17AA39FA_PCI_SUBSYS_384817AA.xml
#   DEV_0257_SUBSYS_17AA39FA_PCI_SUBSYS_384817AA_settings.xml
#   DEV_0257_SUBSYS_17AA39FC_PCI_SUBSYS_387017AA.xml
#   DEV_0257_SUBSYS_17AA39FC_PCI_SUBSYS_387017AA_settings.xml
#   DEV_0257_SUBSYS_17AA39FD_PCI_SUBSYS_385F17AA.xml
#   DEV_0257_SUBSYS_17AA39FE_PCI_SUBSYS_389317AA.xml
#   DEV_0257_SUBSYS_17AA39FF_PCI_SUBSYS_389417AA.xml
#   DEV_0257_SUBSYS_17AA39FF_PCI_SUBSYS_389417AA_settings.xml
#   DEV_0257_SUBSYS_17AA3A03_PCI_SUBSYS_389717AA.xml
#   DEV_0257_SUBSYS_17AA3A04_PCI_SUBSYS_386017AA.xml
#   DEV_0257_SUBSYS_17AA3A04_PCI_SUBSYS_386017AA_settings.xml
#   DEV_0257_SUBSYS_17AA3A05_PCI_SUBSYS_386017AA.xml
#   DEV_0257_SUBSYS_17AA3A05_PCI_SUBSYS_386017AA_settings.xml
#   DEV_0257_SUBSYS_17AA3A06_PCI_SUBSYS_389817AA.xml
#   DEV_0257_SUBSYS_17AA3A07_PCI_SUBSYS_380117AA.xml
#   DEV_0257_SUBSYS_17AA3A08_PCI_SUBSYS_380117AA.xml
#   DEV_0257_SUBSYS_17AA3A09_PCI_SUBSYS_389917AA.xml
#   DEV_0257_SUBSYS_17AA3A0A_PCI_SUBSYS_380117AA.xml
#   DEV_0257_SUBSYS_17AA3A0B_PCI_SUBSYS_380117AA.xml
#   DEV_0257_SUBSYS_17AA3A0D_PCI_SUBSYS_386217AA.xml
#   DEV_0257_SUBSYS_17AA3A0E_PCI_SUBSYS_381317AA.xml
#   DEV_0257_SUBSYS_17AA3A0F_PCI_SUBSYS_380217AA.xml
#   DEV_0257_SUBSYS_17AA3A12_PCI_SUBSYS_386217AA.xml
#   DEV_0257_SUBSYS_17AA3A13_PCI_SUBSYS_386217AA.xml
#   DEV_0257_SUBSYS_17AA3A14_PCI_SUBSYS_386317AA.xml
#   DEV_0257_SUBSYS_17AA3A15_PCI_SUBSYS_386317AA.xml
#   DEV_0257_SUBSYS_17AA3A16_PCI_SUBSYS_386317AA.xml
#   DEV_0257_SUBSYS_17AA3A17_PCI_SUBSYS_386317AA.xml
#   DEV_0257_SUBSYS_17AA3A18_PCI_SUBSYS_380317AA.xml
#   DEV_0257_SUBSYS_17AA3A19_PCI_SUBSYS_386717AA.xml
#   DEV_0257_SUBSYS_17AA3A1A_PCI_SUBSYS_386417AA.xml
#   DEV_0257_SUBSYS_17AA3A1B_PCI_SUBSYS_386517AA.xml
#   DEV_0257_SUBSYS_17AA3A1C_PCI_SUBSYS_386517AA.xml
#   DEV_0257_SUBSYS_17AA3A1D_PCI_SUBSYS_385A17AA.xml
#   DEV_0257_SUBSYS_17AA3A1E_PCI_SUBSYS_385B17AA.xml
#   DEV_0257_SUBSYS_17AA3A1F_PCI_SUBSYS_385C17AA.xml
#   DEV_0257_SUBSYS_17AA3A22_PCI_SUBSYS_386A17AA.xml
#   DEV_0257_SUBSYS_17AA3A23_PCI_SUBSYS_386A17AA.xml
#   DEV_0257_SUBSYS_17AA3A24_PCI_SUBSYS_38A417AA.xml
#   DEV_0257_SUBSYS_17AA3A25_PCI_SUBSYS_380417AA.xml
#   DEV_0257_SUBSYS_17AA3A26_PCI_SUBSYS_384617AA.xml
#   DEV_0257_SUBSYS_17AA3A28_PCI_SUBSYS_384717AA.xml
#   DEV_0257_SUBSYS_17AA3A46_PCI_SUBSYS_384A17AA.xml
#   DEV_0257_SUBSYS_17AA3BCD_PCI_SUBSYS_384A17AA.xml
#   DEV_0257_SUBSYS_17AA3BE6_PCI_SUBSYS_386D17AA.xml
#   DEV_0257_SUBSYS_17AA3BE7_PCI_SUBSYS_386D17AA.xml
#   DEV_0257_SUBSYS_17AA3BEA_PCI_SUBSYS_380A17AA.xml
#   DEV_0257_SUBSYS_17AA3BEE_PCI_SUBSYS_386217AA.xml
#   DEV_0257_SUBSYS_17AA3BEF_PCI_SUBSYS_386217AA.xml
#   DEV_0257_SUBSYS_17AA3BF1_PCI_SUBSYS_386317AA.xml
#   DEV_0257_SUBSYS_17AA3BFE_PCI_SUBSYS_385817AA.xml
#   DEV_0257_SUBSYS_17AA3BFE_PCI_SUBSYS_38B617AA.xml
#   DEV_0257_SUBSYS_17AA3BFF_PCI_SUBSYS_385817AA.xml
#   DEV_0257_SUBSYS_17AA3BFF_PCI_SUBSYS_38B617AA.xml
#   DEV_0257_SUBSYS_17AA3C01_PCI_SUBSYS_385817AA.xml
#   DEV_0257_SUBSYS_17AA3C01_PCI_SUBSYS_38B617AA.xml
#   DEV_0257_SUBSYS_17AA3C02_PCI_SUBSYS_387717AA.xml
#   DEV_0257_SUBSYS_17AA3C03_PCI_SUBSYS_387717AA.xml
#   DEV_0257_SUBSYS_17AA3C04_PCI_SUBSYS_386117AA.xml
#   DEV_0257_SUBSYS_17AA3C06_PCI_SUBSYS_381A17AA.xml
#   DEV_0257_SUBSYS_17AA3C07_PCI_SUBSYS_387C17AA.xml
#   DEV_0257_SUBSYS_17AA3C08_PCI_SUBSYS_387E17AA.xml
#   DEV_0257_SUBSYS_17AA3C09_PCI_SUBSYS_387F17AA.xml
#   DEV_0257_SUBSYS_17AA3C0A_PCI_SUBSYS_387F17AA.xml
#   DEV_0257_SUBSYS_17AA3C0D_PCI_SUBSYS_386017AA.xml
#   DEV_0257_SUBSYS_17AA3C0E_PCI_SUBSYS_385F17AA.xml
#   DEV_0257_SUBSYS_17AA3C0F_PCI_SUBSYS_385F17AA.xml
#   DEV_0257_SUBSYS_17AA3C10_PCI_SUBSYS_385F17AA.xml
#   DEV_0257_SUBSYS_17AA3C10_PCI_SUBSYS_38B717AA.xml
#   DEV_0257_SUBSYS_17AA3C10_PCI_SUBSYS_38BB17AA.xml
#   DEV_0257_SUBSYS_17AA3C11_PCI_SUBSYS_385F17AA.xml
#   DEV_0257_SUBSYS_17AA3C11_PCI_SUBSYS_38B717AA.xml
#   DEV_0257_SUBSYS_17AA3C11_PCI_SUBSYS_38BB17AA.xml
#   DEV_0257_SUBSYS_17AA3C12_PCI_SUBSYS_386517AA.xml
#   DEV_0257_SUBSYS_17AA3C13_PCI_SUBSYS_386617AA.xml
#   DEV_0257_SUBSYS_17AA3C14_PCI_SUBSYS_388317AA.xml
#   DEV_0257_SUBSYS_17AA3C15_PCI_SUBSYS_388317AA.xml
#   DEV_0257_SUBSYS_17AA3C1A_PCI_SUBSYS_388617AA.xml
#   DEV_0257_SUBSYS_17AA3C1B_PCI_SUBSYS_388617AA.xml
#   DEV_0257_SUBSYS_17AA3CAF_PCI_SUBSYS_388D17AA.xml
#   DEV_0257_SUBSYS_17AA3CB6_PCI_SUBSYS_380217AA.xml
#   DEV_0257_SUBSYS_17AA3CB7_PCI_SUBSYS_380217AA.xml
#   DEV_0257_SUBSYS_17AA3CB9_PCI_SUBSYS_389617AA.xml
#   DEV_0257_SUBSYS_17AA3CBA_PCI_SUBSYS_389617AA.xml
#   DEV_0257_SUBSYS_17AA3CBB_PCI_SUBSYS_389317AA.xml
#   DEV_0257_SUBSYS_17AA3CC0_PCI_SUBSYS_386717AA.xml
#   DEV_0257_SUBSYS_17AA3CC1_PCI_SUBSYS_386717AA.xml
#   DEV_0257_SUBSYS_17AA3CC2_PCI_SUBSYS_381B17AA.xml
#   DEV_0257_SUBSYS_17AA3CC3_PCI_SUBSYS_381C17AA.xml
#   DEV_0257_SUBSYS_17AA3D76_PCI_SUBSYS_381D17AA.xml
#   DEV_0257_SUBSYS_17AA3D78_PCI_SUBSYS_389F17AA.xml
#   DEV_0257_SUBSYS_17AA3D79_PCI_SUBSYS_389F17AA.xml
#   DEV_0257_SUBSYS_17AA3D7B_PCI_SUBSYS_389C17AA.xml
#   DEV_0257_SUBSYS_17AA3D7C_PCI_SUBSYS_389C17AA.xml
#   DEV_0257_SUBSYS_17AA3D7D_PCI_SUBSYS_389B17AA.xml
#   DEV_0257_SUBSYS_17AA3D7E_PCI_SUBSYS_389B17AA.xml
#   DEV_0257_SUBSYS_17AA3D7F_PCI_SUBSYS_386917AA.xml
#   DEV_0257_SUBSYS_17AA3D80_PCI_SUBSYS_386917AA.xml
#   DEV_0257_SUBSYS_17AA3D81_PCI_SUBSYS_386917AA.xml
#   DEV_0257_SUBSYS_17AA3D8D_PCI_SUBSYS_381A17AA.xml
#   DEV_0257_SUBSYS_17AA3D92_PCI_SUBSYS_38A117AA.xml
#   DEV_0257_SUBSYS_17AA3D95_PCI_SUBSYS_38A117AA.xml
#   DEV_0257_SUBSYS_17AA3D96_PCI_SUBSYS_380517AA.xml
#   DEV_0274_SUBSYS_17AA371E_PCI_SUBSYS_371E17AA.xml
#   DEV_0274_SUBSYS_17AA371F_PCI_SUBSYS_371F17AA.xml
#   DEV_0274_SUBSYS_17AA3720_PCI_SUBSYS_372017AA.xml
#   DEV_0274_SUBSYS_17AA3734_PCI_SUBSYS_373417AA.xml
#   DEV_0274_SUBSYS_17AA3739_PCI_SUBSYS_373917AA.xml
#   DEV_0274_SUBSYS_17AA373A_PCI_SUBSYS_373A17AA.xml
#   DEV_0274_SUBSYS_17AA373B_PCI_SUBSYS_373B17AA.xml
#   DEV_0274_SUBSYS_17AA3751_PCI_SUBSYS_375117AA.xml
#   DEV_0274_SUBSYS_17AA3757_PCI_SUBSYS_375717AA.xml
#   DEV_0274_SUBSYS_17AA3763_PCI_SUBSYS_376317AA.xml
#   DEV_0274_SUBSYS_17AA3764_PCI_SUBSYS_376417AA.xml
#   DEV_0274_SUBSYS_17AA3767_PCI_SUBSYS_376717AA.xml
#   DEV_0274_SUBSYS_17AA376C_PCI_SUBSYS_376417AA.xml
#   DEV_0274_SUBSYS_17AA3778_PCI_SUBSYS_377817AA.xml
#   DEV_0274_SUBSYS_17AA377A_PCI_SUBSYS_377A17AA.xml
#   DEV_0274_SUBSYS_17AA377B_PCI_SUBSYS_377B17AA.xml
#   DEV_0274_SUBSYS_17AA377C_PCI_SUBSYS_377C17AA.xml
#   DEV_0274_SUBSYS_17AA377D_PCI_SUBSYS_377B17AA.xml
#   DEV_0285_SUBSYS_17AA3803_PCI_SUBSYS_382717AA.xml
#   DEV_0285_SUBSYS_17AA3804_PCI_SUBSYS_380317AA.xml
#   DEV_0285_SUBSYS_17AA3806_PCI_SUBSYS_380617AA.xml
#   DEV_0285_SUBSYS_17AA3807_PCI_SUBSYS_382417AA.xml
#   DEV_0285_SUBSYS_17AA380C_PCI_SUBSYS_380F17AA.xml
#   DEV_0285_SUBSYS_17AA380E_PCI_SUBSYS_383A17AA.xml
#   DEV_0285_SUBSYS_17AA3813_PCI_SUBSYS_381017AA.xml
#   DEV_0285_SUBSYS_17AA3818_PCI_SUBSYS_380317AA.xml
#   DEV_0285_SUBSYS_17AA383B_PCI_SUBSYS_382717AA.xml
#   DEV_0285_SUBSYS_17AA383C_PCI_SUBSYS_382517AA.xml
#   DEV_0285_SUBSYS_17AA383D_PCI_SUBSYS_382417AA.xml
#   DEV_0285_SUBSYS_17AA383E_PCI_SUBSYS_382517AA.xml
#   DEV_0287_SUBSYS_17AA3801_PCI_SUBSYS_381C17AA.xml
#   DEV_0287_SUBSYS_17AA3802_PCI_SUBSYS_382017AA.xml
#   DEV_0287_SUBSYS_17AA3809_PCI_SUBSYS_380917AA.xml
#   DEV_0287_SUBSYS_17AA380A_PCI_SUBSYS_380A17AA.xml
#   DEV_0287_SUBSYS_17AA380B_PCI_SUBSYS_380A17AA.xml
#   DEV_0287_SUBSYS_17AA380D_PCI_SUBSYS_380D17AA.xml
#   DEV_0287_SUBSYS_17AA3811_PCI_SUBSYS_381117AA.xml
#   DEV_0287_SUBSYS_17AA3812_PCI_SUBSYS_381117AA.xml
#   DEV_0287_SUBSYS_17AA3813_PCI_SUBSYS_382617AA.xml
#   DEV_0287_SUBSYS_17AA3818_PCI_SUBSYS_380A17AA.xml
#   DEV_0287_SUBSYS_17AA3819_PCI_SUBSYS_381717AA.xml
#   DEV_0287_SUBSYS_17AA381A_PCI_SUBSYS_381A17AA.xml
#   DEV_0287_SUBSYS_17AA381B_PCI_SUBSYS_380517AA.xml
#   DEV_0287_SUBSYS_17AA381C_PCI_SUBSYS_380117AA.xml
#   DEV_0287_SUBSYS_17AA3822_PCI_SUBSYS_381117AA.xml
#   DEV_0287_SUBSYS_17AA3838_PCI_SUBSYS_383817AA.xml
#   DEV_0287_SUBSYS_17AA3839_PCI_SUBSYS_382617AA.xml
#   DEV_0287_SUBSYS_17AA383A_PCI_SUBSYS_380817AA.xml
#   DEV_0287_SUBSYS_17AA3843_PCI_SUBSYS_381E17AA.xml
#   DEV_0287_SUBSYS_17AA3844_PCI_SUBSYS_382717AA.xml
#   DEV_0287_SUBSYS_17AA384A_PCI_SUBSYS_383217AA.xml
#   DEV_0287_SUBSYS_17AA384D_PCI_SUBSYS_383617AA.xml
#   DEV_0287_SUBSYS_17AA384F_PCI_SUBSYS_383517AA.xml
#   DEV_0287_SUBSYS_17AA3852_PCI_SUBSYS_383217AA.xml
#   DEV_0287_SUBSYS_17AA3853_PCI_SUBSYS_383217AA.xml
#   DEV_0287_SUBSYS_17AA3856_PCI_SUBSYS_383B17AA.xml
#   DEV_0287_SUBSYS_17AA3858_PCI_SUBSYS_383C17AA.xml
#   DEV_0287_SUBSYS_17AA385A_PCI_SUBSYS_384117AA.xml
#   DEV_0287_SUBSYS_17AA385B_PCI_SUBSYS_383617AA.xml
#   DEV_0287_SUBSYS_17AA3863_PCI_SUBSYS_381C17AA.xml
#   DEV_0287_SUBSYS_17AA3864_PCI_SUBSYS_381317AA.xml
#   DEV_0287_SUBSYS_17AA3865_PCI_SUBSYS_380D17AA.xml
#   DEV_0287_SUBSYS_17AA3866_PCI_SUBSYS_380D17AA.xml
#   DEV_0287_SUBSYS_17AA3867_PCI_SUBSYS_380217AA.xml
#   DEV_0287_SUBSYS_17AA3869_PCI_SUBSYS_380F17AA.xml
#   DEV_0287_SUBSYS_17AA386A_PCI_SUBSYS_380F17AA.xml
#   DEV_0287_SUBSYS_17AA386B_PCI_SUBSYS_387917AA.xml
#   DEV_0287_SUBSYS_17AA386D_PCI_SUBSYS_387917AA.xml
#   DEV_0287_SUBSYS_17AA3870_PCI_SUBSYS_385717AA.xml
#   DEV_0287_SUBSYS_17AA3871_PCI_SUBSYS_385817AA.xml
#   DEV_0287_SUBSYS_17AA3872_PCI_SUBSYS_383417AA.xml
#   DEV_0287_SUBSYS_17AA3873_PCI_SUBSYS_383517AA.xml
#   DEV_0287_SUBSYS_17AA3875_PCI_SUBSYS_389117AA.xml
#   DEV_0287_SUBSYS_17AA387D_PCI_SUBSYS_383517AA.xml
#   DEV_0287_SUBSYS_17AA387E_PCI_SUBSYS_383517AA.xml
#   DEV_0287_SUBSYS_17AA3881_PCI_SUBSYS_384317AA.xml
#   DEV_0287_SUBSYS_17AA3893_PCI_SUBSYS_384C17AA.xml
#   DEV_0287_SUBSYS_17AA3894_PCI_SUBSYS_386617AA.xml
#   DEV_0287_SUBSYS_17AA3895_PCI_SUBSYS_380117AA.xml
#   DEV_0287_SUBSYS_17AA3896_PCI_SUBSYS_380117AA.xml
#   DEV_0287_SUBSYS_17AA3899_PCI_SUBSYS_383F17AA.xml
#   DEV_0287_SUBSYS_17AA389A_PCI_SUBSYS_383F17AA.xml
#   DEV_0287_SUBSYS_17AA389B_PCI_SUBSYS_386C17AA.xml
#   DEV_0287_SUBSYS_17AA389C_PCI_SUBSYS_384517AA.xml
#   DEV_0287_SUBSYS_17AA389E_PCI_SUBSYS_386617AA.xml
#   DEV_0287_SUBSYS_17AA38A0_PCI_SUBSYS_386E17AA.xml
#   DEV_0287_SUBSYS_17AA38A9_PCI_SUBSYS_384D17AA.xml
#   DEV_0287_SUBSYS_17AA38AB_PCI_SUBSYS_384D17AA.xml
#   DEV_0287_SUBSYS_17AA38AD_PCI_SUBSYS_384E17AA.xml
#   DEV_0287_SUBSYS_17AA38B0_PCI_SUBSYS_384E17AA.xml
#   DEV_0287_SUBSYS_17AA38B1_PCI_SUBSYS_385217AA.xml
#   DEV_0287_SUBSYS_17AA38B2_PCI_SUBSYS_385917AA.xml
#   DEV_0287_SUBSYS_17AA38BA_PCI_SUBSYS_387917AA.xml
#   DEV_0287_SUBSYS_17AA38BB_PCI_SUBSYS_387917AA.xml
#   DEV_0287_SUBSYS_17AA38BE_PCI_SUBSYS_380217AA.xml
#   DEV_0287_SUBSYS_17AA38BF_PCI_SUBSYS_380217AA.xml
#   DEV_0287_SUBSYS_17AA38C0_PCI_SUBSYS_387D17AA.xml
#   DEV_0287_SUBSYS_17AA38C1_PCI_SUBSYS_387D17AA.xml
#   DEV_0287_SUBSYS_17AA38C5_PCI_SUBSYS_388117AA.xml
#   DEV_0287_SUBSYS_17AA38C6_PCI_SUBSYS_388217AA.xml
#   DEV_0287_SUBSYS_17AA38C7_PCI_SUBSYS_380817AA.xml
#   DEV_0287_SUBSYS_17AA38C8_PCI_SUBSYS_380817AA.xml
#   DEV_0287_SUBSYS_17AA38CE_PCI_SUBSYS_384617AA.xml
#   DEV_0287_SUBSYS_17AA38CF_PCI_SUBSYS_384717AA.xml
#   DEV_0287_SUBSYS_17AA38D0_PCI_SUBSYS_389017AA.xml
#   DEV_0287_SUBSYS_17AA38D1_PCI_SUBSYS_389117AA.xml
#   DEV_0287_SUBSYS_17AA38D2_PCI_SUBSYS_382917AA.xml
#   DEV_0287_SUBSYS_17AA38D3_PCI_SUBSYS_381117AA.xml
#   DEV_0287_SUBSYS_17AA38D4_PCI_SUBSYS_381117AA.xml
#   DEV_0287_SUBSYS_17AA38D5_PCI_SUBSYS_381117AA.xml
#   DEV_0287_SUBSYS_17AA38D6_PCI_SUBSYS_381117AA.xml
#   DEV_0287_SUBSYS_17AA38D7_PCI_SUBSYS_382917AA.xml
#   DEV_0287_SUBSYS_17AA38D8_PCI_SUBSYS_383917AA.xml
#   DEV_0287_SUBSYS_17AA38DB_PCI_SUBSYS_382F17AA.xml
#   DEV_0287_SUBSYS_17AA38DC_PCI_SUBSYS_382F17AA.xml
#   DEV_0287_SUBSYS_17AA38F8_PCI_SUBSYS_380317AA.xml
#   DEV_0287_SUBSYS_17AA38F9_PCI_SUBSYS_3D8B17AA.xml
#   DEV_0287_SUBSYS_17AA38FA_PCI_SUBSYS_3D8B17AA.xml
#   DEV_0287_SUBSYS_17AA38FD_PCI_SUBSYS_380C17AA.xml
#   DEV_0287_SUBSYS_17AA38FE_PCI_SUBSYS_38A017AA.xml
#   DEV_0287_SUBSYS_17AA38FF_PCI_SUBSYS_38A017AA.xml
#   DEV_0287_SUBSYS_17AA3A34_PCI_SUBSYS_3A3417AA.xml
#   DEV_0287_SUBSYS_17AA3A35_PCI_SUBSYS_3A3517AA.xml
#   DEV_0287_SUBSYS_17AA3A36_PCI_SUBSYS_3A3517AA.xml
#   DEV_0298_SUBSYS_17AA3819_PCI_SUBSYS_380E17AA.xml
#   DEV_0298_SUBSYS_17AA381B_PCI_SUBSYS_380217AA.xml
#   DEV_0298_SUBSYS_17AA3822_PCI_SUBSYS_383617AA.xml
#   DEV_0887_SUBSYS_17AA3717_PCI_SUBSYS_371717AA.xml
#   DEV_0892_SUBSYS_17AA3715_PCI_SUBSYS_371517AA.xml
#   DEV_0892_SUBSYS_17AA3716_PCI_SUBSYS_371617AA.xml
#   DEV_0897_SUBSYS_17AA3715_PCI_SUBSYS_371517AA.xml
#   DEV_0897_SUBSYS_17AA3716_PCI_SUBSYS_371617AA.xml
#   DEV_0897_SUBSYS_17AA374F_PCI_SUBSYS_374F17AA.xml
#   HDAUDIO_DEV_0235_SUBSYS_17AA370B_PCI_SUBSYS_370B17AA.xml
#   HDAUDIO_DEV_0235_SUBSYS_17AA370C_PCI_SUBSYS_370C17AA.xml
#   HDAUDIO_DEV_0235_SUBSYS_17AA370D_PCI_SUBSYS_36FB17AA.xml
#   HDAUDIO_DEV_0235_SUBSYS_17AA370E_PCI_SUBSYS_36FA17AA.xml
#   HDAUDIO_DEV_0235_SUBSYS_17AA370F_PCI_SUBSYS_36FF17AA.xml
#   HDAUDIO_DEV_0235_SUBSYS_17AA3710_PCI_SUBSYS_36FE17AA.xml
#   HDAUDIO_DEV_0235_SUBSYS_17AA3711_PCI_SUBSYS_36FD17AA.xml
#   HDAUDIO_DEV_0235_SUBSYS_17AA3712_PCI_SUBSYS_36FC17AA.xml
#   HDAUDIO_DEV_0235_SUBSYS_17AA3713_PCI_SUBSYS_370517AA.xml
#   HDAUDIO_DEV_0235_SUBSYS_17AA3718_PCI_SUBSYS_371817AA.xml
#   HDAUDIO_DEV_0235_SUBSYS_17AA3719_PCI_SUBSYS_371917AA.xml
#   HDAUDIO_DEV_0257_SUBSYS_17AA3808_PCI_SUBSYS_381417AA.xml
#   HDAUDIO_DEV_0257_SUBSYS_17AA380D_PCI_SUBSYS_381417AA.xml
#   HDAUDIO_DEV_0257_SUBSYS_17AA380E_PCI_SUBSYS_381417AA.xml
#   HDAUDIO_DEV_0257_SUBSYS_17AA381E_PCI_SUBSYS_381417AA.xml
#   HDAUDIO_DEV_0274_SUBSYS_17AA3703_PCI_SUBSYS_370317AA.xml
#   Headphone_Default_Generic_Default_Atmos3.7.xml
#   INTELAUDIO_DEV_0257_SUBSYS_17AA3805_PCI_SUBSYS_381617AA.xml
#   INTELAUDIO_DEV_0257_SUBSYS_17AA3806_PCI_SUBSYS_381617AA.xml
#   INTELAUDIO_DEV_0257_SUBSYS_17AA3807_PCI_SUBSYS_381617AA.xml
#   INTELAUDIO_DEV_0257_SUBSYS_17AA3809_PCI_SUBSYS_381617AA.xml
#   INTELAUDIO_DEV_0257_SUBSYS_17AA380A_PCI_SUBSYS_381617AA.xml
#   INTELAUDIO_DEV_0257_SUBSYS_17AA383C_PCI_SUBSYS_381017AA.xml
#   INTELAUDIO_DEV_0257_SUBSYS_17AA383D_PCI_SUBSYS_381017AA.xml
#   INTELAUDIO_DEV_0257_SUBSYS_17AA383E_PCI_SUBSYS_381017AA.xml
#   INTELAUDIO_DEV_0257_SUBSYS_17AA383F_PCI_SUBSYS_381017AA.xml
#   INTELAUDIO_DEV_0257_SUBSYS_17AA3840_PCI_SUBSYS_381017AA.xml
#   INTELAUDIO_DEV_0257_SUBSYS_17AA3845_PCI_SUBSYS_382117AA.xml
#   INTELAUDIO_DEV_0257_SUBSYS_17AA3847_PCI_SUBSYS_382117AA.xml
#   INTELAUDIO_DEV_0257_SUBSYS_17AA3848_PCI_SUBSYS_382117AA.xml
#   INTELAUDIO_DEV_0257_SUBSYS_17AA3849_PCI_SUBSYS_382117AA.xml
#   INTELAUDIO_DEV_0257_SUBSYS_17AA384A_PCI_SUBSYS_382117AA.xml
#   INTELAUDIO_DEV_0257_SUBSYS_17AA384B_PCI_SUBSYS_382117AA.xml
#   INTELAUDIO_DEV_0274_SUBSYS_17AA3702_PCI_SUBSYS_370217AA.xml
#   INTELAUDIO_DEV_0285_SUBSYS_17AA381A_PCI_SUBSYS_380417AA.xml
#   INTELAUDIO_DEV_0298_SUBSYS_17AA3818_PCI_SUBSYS_382E17AA.xml
#   Operator_Info_Lenovo.xml
#   operator_settings.xml
#   operator_settings_lenovo_audio_auto_profile.json
#   operator_settings_lenovo_audio_mirroring.json
#   operator_settings_lenovo_audio_mirroring_amd.json
#   operator_settings_lenovo_auto_profile.json
#   operator_settings_lenovo_default.json
#   operator_settings_lenovo_disable_vl_feedback.json
#   operator_settings_lenovo_edu.json
#   operator_settings_lenovo_override_volume.json
#   operator_settings_lenovo_override_volume_edu.json
#   operator_settings_lenovo_remove_logo.json
# ----------------------------------------
# Корневая директория: D:\LenovoDrivers\LenovoThinkbook16G6+IMH\Drivers from Saler\Audio\3rd party\Dolby\swc_factory_3.6
# Поддиректории:
#   swc_aposvc_20h1_21h2_22h2_b25640_v3.30600.623.0
#   swc_hsa_19h1_20h1_21h2_22h2_b14302_v3.30201.210.0
# Файлов нет
# ----------------------------------------
# Корневая директория: D:\LenovoDrivers\LenovoThinkbook16G6+IMH\Drivers from Saler\Audio\3rd party\Dolby\swc_factory_3.6\swc_aposvc_20h1_21h2_22h2_b25640_v3.30600.623.0
# Поддиректорий нет
# Файлы:
#   CaptureStreamMonitor.dll
#   DAX3API.exe
#   Dax3DapControl.dll
#   Dax3Ref.dll
#   dax3_swc_aposvc.cat
#   dax3_swc_aposvc.inf
#   DAXSSID.dll
#   default_settings.json
#   Default_settings.xml
#   DolbyAPONs.dll
#   DolbyAPONs30.dll
#   DolbyAPOv2100.dll
#   DolbyAPOv251.dll
#   DolbyAPOvlldp.dll
#   DolbyAPOvlldp120.dll
#   DolbyAPOvlldp130.dll
#   DolbyAPOvlldp140.dll
#   DolbyAPOvlldp150.dll
#   DolbyApoVr.dll
#   DolbyDax3Apo.dll
# ----------------------------------------
# Корневая директория: D:\LenovoDrivers\LenovoThinkbook16G6+IMH\Drivers from Saler\Audio\3rd party\Dolby\swc_factory_3.6\swc_hsa_19h1_20h1_21h2_22h2_b14302_v3.30201.210.0
# Поддиректорий нет
# Файлы:
#   dax3_swc_hsa.cat
#   dax3_swc_hsa.inf
# ----------------------------------------
# Корневая директория: D:\LenovoDrivers\LenovoThinkbook16G6+IMH\Drivers from Saler\Audio\3rd party\Elevoc
# Поддиректории:
#   DMICEXT
#   ElevocAPO64
#   ElevocAPO64Ext
# Файлов нет
# ----------------------------------------
# Корневая директория: D:\LenovoDrivers\LenovoThinkbook16G6+IMH\Drivers from Saler\Audio\3rd party\Elevoc\DMICEXT
# Поддиректорий нет
# Файлы:
#   intcdmicext_e.cat
#   IntcDMicExt_E.inf
# ----------------------------------------
# Корневая директория: D:\LenovoDrivers\LenovoThinkbook16G6+IMH\Drivers from Saler\Audio\3rd party\Elevoc\ElevocAPO64
# Поддиректорий нет
# Файлы:
#   elevocapo.cat
#   ElevocAPO64.inf
#   ElevocAudioManager.exe
#   ElevocControlService.exe
#   ElevocDAPO.dll
#   ElevocDNSEngine.dll
#   ElevocGNA.dll
#   ElevocKWSApo.dll
#   ElevocSEEngine.dll
#   ElevocUAPO.dll
#   elevoc_cns.dll
#   elevoc_core_engine.dll
#   elevoc_engine.dll
#   elevoc_gns.dll
#   elevoc_kwsfourmic.dll
#   elevoc_kwstwomic.dll
#   elevoc_kws_engine.dll
#   elevoc_speechfourmic.dll
#   elevoc_speechfourmic_engine.dll
#   elevoc_speechtwomic.dll
#   elevoc_speech_engine.dll
#   elevoc_s_cns.dll
#   elevoc_teamsaec.dll
#   elevoc_teamsagc.dll
#   elevoc_teamseq.dll
#   elevoc_teamstestmode.dll
#   elevoc_tradition_ns.dll
#   elevoc_voice_separation.dll
#   fmt.dll
#   gna.dll
#   msvcp140.dll
#   npu_driver_compiler_adapter.dll
#   npu_level_zero_backend.dll
#   npu_mlir_compiler.dll
#   openvino.dll
#   openvino_auto_plugin.dll
#   openvino_c.dll
#   openvino_hetero_plugin.dll
#   openvino_intel_cpu_plugin.dll
#   openvino_intel_gna_plugin.dll
#   openvino_intel_npu_plugin.dll
#   plugins.xml
#   tbb12.dll
#   vcruntime140.dll
#   vcruntime140_1.dll
# ----------------------------------------
# Корневая директория: D:\LenovoDrivers\LenovoThinkbook16G6+IMH\Drivers from Saler\Audio\3rd party\Elevoc\ElevocAPO64Ext
# Поддиректорий нет
# Файлы:
#   ElevocAPO64Ext.inf
#   elevocapoext.cat
#   ELE_BWE_M_C.raw
#   ELE_BWE_M_C2.raw
#   ELE_CG_17AA38C7_0287
#   ELE_CG_17AA38C9_0287
#   ELE_CG_17AA38CB_0287
#   ELE_CG_17AA38CD_0287
#   ELE_CG_17AA38CE_0287
#   ELE_CG_17AA38CF_0287
#   ELE_CG_17AA38D0_0287
#   ELE_CG_17AA38D1_0287
#   ELE_CG_17AA38D2_0287
#   ELE_CG_17AA38D3_0287
#   ELE_CG_17AA38D8_0287
#   ELE_CG_17AA38DF_0287
#   ELE_CG_17AA38E0_0287
#   ELE_CG_17AA38F8_0287
#   ELE_CG_17AA38F9_0287
#   ELE_CG_17AA38FD_0287
#   ELE_CG_17AA3C06_0257
#   ELE_CG_17AA3C22_0257
#   ELE_CG_17AA3CAF_0257
#   ELE_CG_17AA3CB3_0257
#   ELE_CG_17AA3CB4_0257
#   ELE_CG_17AA3CB6_0257
#   ELE_CG_17AA3CB9_0257
#   ELE_CG_17AA3CBA_0257
#   ELE_CG_17AA3CBB_0257
#   ELE_CG_17AA3CC0_0257
#   ELE_CG_17AA3CC2_0257
#   ELE_CG_17AA3D76_0257
#   ELE_CG_17AA3D78_0257
#   ELE_CG_17AA3D79_0257
#   ELE_CG_17AA3D7B_0257
#   ELE_CG_17AA3D7C_0257
#   ELE_CG_17AA3D7D_0257
#   ELE_CG_17AA3D7E_0257
#   ELE_CG_17AA3D7F_0257
#   ELE_CG_17AA3D80_0257
#   ELE_CG_17AA3D81_0257
#   ELE_CG_17AA3D8E_0257
#   ELE_CG_17AA3D91_0257
#   ELE_CG_17AA3D92_0257
#   ELE_CG_17AA3D95_0257
#   ELE_CG_17AA3D96_0257
#   ELE_CG_17AA50E1_1F86
#   ELE_CG_17AA50EC_1F86
#   ELE_DMIC_103.dat
#   ELE_DMIC_120.dat
#   ELE_DMIC_50.dat
#   ELE_DMIC_56.dat
#   ELE_DMIC_75.dat
#   ELE_DMIC_84.dat
#   ELE_DMIC_90.dat
#   ELE_DMIC_96.dat
#   ELE_DMIC_CR_M_50.raw
#   ELE_DMIC_M_103.raw
#   ELE_DMIC_M_120.raw
#   ELE_DMIC_M_50.raw
#   ELE_DMIC_M_56.raw
#   ELE_DMIC_M_75.raw
#   ELE_DMIC_M_84.raw
#   ELE_DMIC_M_90.raw
#   ELE_DMIC_M_96.raw
#   ELE_DMIC_M_C_50.raw
#   ELE_DMIC_M_C_56.raw
#   ELE_DMIC_M_C_75.raw
#   ELE_DMIC_M_C_84.raw
#   ELE_DMIC_M_C_90.raw
#   ELE_DMIC_M_C_93.raw
#   ELE_DMIC_M_C_96.raw
#   ELE_NS_DM_C.raw
#   ELE_NS_S1M_C.raw
#   ELE_NS_S2M_C.raw
#   ELE_SA_DM_C.raw
#   ELE_SE_DMIC_103.dat
#   ELE_SE_DMIC_120.dat
#   ELE_SE_DMIC_120D_50.dat
#   ELE_SE_DMIC_50.dat
#   ELE_SE_DMIC_56.dat
#   ELE_SE_DMIC_75.dat
#   ELE_SE_DMIC_84.dat
#   ELE_SE_DMIC_90.dat
#   ELE_SE_DMIC_96.dat
#   ELE_SE_DMIC_C.dat
#   ELE_SE_DM_C.raw
#   ELE_SE_DM_C2.raw
#   ELE_SE_M_103.raw
#   ELE_SE_M_120.raw
#   ELE_SE_M_120D_50.raw
#   ELE_SE_M_50.raw
#   ELE_SE_M_56.raw
#   ELE_SE_M_75.raw
#   ELE_SE_M_84.raw
#   ELE_SE_M_90.raw
#   ELE_SE_M_96.raw
#   ELE_SMIC_CR_M.raw
#   ELE_SMIC_M.raw
#   ELE_SMIC_M_C.raw
#   RTMICAR_17AA38CB.DAT
#   RTMICAR_17AA38CD.DAT
#   RTMICAR_17AA38D0.DAT
#   RTMICAR_17AA38D1.DAT
#   RTMICAR_17AA38DF.DAT
#   RTMICAR_17AA38E0.DAT
#   RTMICAR_17AA3C22.DAT
#   RTMICAR_17AA3CAF.DAT
#   RTMICAR_17AA3CB3.DAT
#   RTMICAR_17AA3CB4.DAT
#   RTMICAR_17AA3CB9.DAT
#   RTMICAR_17AA3CBA.DAT
#   RTMICAR_17AA3D78.DAT
#   RTMICAR_17AA3D79.DAT
#   RTMICAR_17AA3D7B.DAT
#   RTMICAR_17AA3D7C.DAT
#   RTMICAR_17AA3D7D.DAT
#   RTMICAR_17AA3D7E.DAT
#   RTMICAR_17AA3D7F.DAT
#   RTMICAR_17AA3D80.DAT
#   RTMICAR_17AA3D81.DAT
#   RTMICAR_17AA3D8E.DAT
#   RTMICAR_17AA3D91.DAT
#   RTMICAR_17AA3D92.DAT
#   RTMICAR_17AA3D95.DAT
#   RTMICAR_17AA3D96.DAT
# ----------------------------------------
# Корневая директория: D:\LenovoDrivers\LenovoThinkbook16G6+IMH\Drivers from Saler\Audio\ExtRtk_IntcOED
# Поддиректорий нет
# Файлы:
#   intcoed_oemlibpath.cat
#   IntcOED_OemLibPath.inf
#   mtl_elliptic_lib.bin
#   mtl_rtksep481_lib.bin
#   mtl_vlldp15xlite_2inst_lib.bin
#   mtl_vlldp15x_2inst_lib.bin
# ----------------------------------------
# Корневая директория: D:\LenovoDrivers\LenovoThinkbook16G6+IMH\Drivers from Saler\Audio\Realtek
# Поддиректории:
#   Codec_9597.1
#   ExtRtk_9597.1
#   RealtekService_664
#   RealtekUAPO2_12_241
#   RealtekUAPO2_13_241
# Файлов нет
# ----------------------------------------
# Корневая директория: D:\LenovoDrivers\LenovoThinkbook16G6+IMH\Drivers from Saler\Audio\Realtek\Codec_9597.1
# Поддиректорий нет
# Файлы:
#   HDXLVSST.inf
#   hdxrt.cat
#   RTAIODAT.DAT
#   RTKVHD64.sys
# ----------------------------------------
# Корневая директория: D:\LenovoDrivers\LenovoThinkbook16G6+IMH\Drivers from Saler\Audio\Realtek\ExtRtk_9597.1
# Поддиректорий нет
# Файлы:
#   hdxrtext.cat
#   HDX_LenovoExt_DOLBY_Wrap36_ELEVOC_Whisper3.0.inf
# ----------------------------------------
# Корневая директория: D:\LenovoDrivers\LenovoThinkbook16G6+IMH\Drivers from Saler\Audio\Realtek\RealtekService_664
# Поддиректорий нет
# Файлы:
#   MonoSeparationEnrollDll.dll
#   realtekservice.cat
#   RealtekService.inf
#   RtCOM64.dll
#   RtDataProc64.dll
#   RtkApi64U.dll
#   RtkAudUService64.exe
#   RtkAudUServiceConf64.dll
#   RtkAudUServiceRes64.dll
#   RtkCfg64.dll
#   SpeakerVerfDll.dll
# ----------------------------------------
# Корневая директория: D:\LenovoDrivers\LenovoThinkbook16G6+IMH\Drivers from Saler\Audio\Realtek\RealtekUAPO2_12_241
# Поддиректорий нет
# Файлы:
#   realtekapo2.cat
#   RealtekUAPO2.inf
#   RltkAPOU642.dll
#   RtkIntU642.dll
#   RtkMicUUn642.dll
#   RtkUApo2Api.dll
# ----------------------------------------
# Корневая директория: D:\LenovoDrivers\LenovoThinkbook16G6+IMH\Drivers from Saler\Audio\Realtek\RealtekUAPO2_13_241
# Поддиректорий нет
# Файлы:
#   realtekapo2.cat
#   RealtekUAPO2.inf
#   RltkAPOU642.dll
#   RtkIntU642.dll
#   RtkMicUUn642.dll
#   RtkUApo2Api.dll
# ----------------------------------------
# Корневая директория: D:\LenovoDrivers\LenovoThinkbook16G6+IMH\Drivers from Saler\Audio\SST9870
# Поддиректории:
#   AS
#   Cfg
#   Fw
#   IntelMvaExtensionInf
#   Libs
#   Topology
#   WoV
# Файлы:
#   detectionverificationdrv.cat
#   DetectionVerificationDrv.dll
#   DetectionVerificationDrv.inf
#   intcaudiobus.cat
#   IntcAudioBus.inf
#   IntcAudioBus.sys
#   intcaudiosensors.cat
#   IntcAudioSensors.dll
#   IntcAudioSensors.inf
#   intcbtau.cat
#   IntcBTAu.inf
#   IntcBTAu.sys
#   intcbtle.cat
#   IntcBtLE.inf
#   IntcBtLE.sys
#   intcdmic.cat
#   IntcDMic.inf
#   IntcDMic.sys
#   intcoed.cat
#   IntcOED.inf
#   IntcOED.sys
#   intcsdw.cat
#   IntcSDW.inf
#   IntcSDW.sys
#   intcsdwbus.cat
#   IntcSdwBus.inf
#   IntcSdwBus.sys
#   intcsst.cat
#   IntcSST.inf
#   IntcSST.sys
#   intcstreaming.cat
#   IntcStreaming.inf
#   IntcStreaming.sys
#   intcusb.cat
#   IntcUSB.inf
#   IntcUSB.sys
#   IntelSSTPreprocStreamer.dll
#   IntelWovSDK.dll
#   lt6911au.cat
#   LT6911Au.inf
#   LT6911Au.sys
#   MultiChannelWoV.dll
#   MultichannelWoVCfg.dll
#   WakeWordEngine.dll
# ----------------------------------------
# Корневая директория: D:\LenovoDrivers\LenovoThinkbook16G6+IMH\Drivers from Saler\Audio\SST9870\AS
# Поддиректории:
#   DLLs
#   IAS
#   MultiPaOemDll
# Файлов нет
# ----------------------------------------
# Корневая директория: D:\LenovoDrivers\LenovoThinkbook16G6+IMH\Drivers from Saler\Audio\SST9870\AS\DLLs
# Поддиректорий нет
# Файлы:
#   IntelAcaDll.dll
#   IntelAcaDll.NetFull.dll
#   IntelAudioDll_x64.dll
#   IntelDetectorCom.dll
#   IntelMultiPaSetupDll.dll
# ----------------------------------------
# Корневая директория: D:\LenovoDrivers\LenovoThinkbook16G6+IMH\Drivers from Saler\Audio\SST9870\AS\IAS
# Поддиректории:
#   Cfg
# Файлы:
#   ControlModule.dll
#   DetectionVerificationDrv.dll
#   IntelAudioService.exe
#   IntelAudioService.exe.config
#   IntelSSTPreprocStreamer.dll
#   NativeApiAdapter.dll
#   RpcServer.dll
#   WppLoggerDll.dll
# ----------------------------------------
# Корневая директория: D:\LenovoDrivers\LenovoThinkbook16G6+IMH\Drivers from Saler\Audio\SST9870\AS\IAS\Cfg
# Поддиректорий нет
# Файлы:
#   aec_asr_str_def_1ch_in.tf
#   aec_asr_str_def_2ch_in.tf
#   aec_asr_str_def_2ch_in_gna.tf
#   aec_asr_str_def_4ch_in.tf
#   aec_asr_str_def_4ch_in_gna.tf
#   aec_dns_str_def_1ch_in_48k_gna.tf
#   aec_dns_str_def_1ch_in_gna.tf
#   aec_dns_str_def_2ch_in_48k_gna.tf
#   aec_dns_str_def_2ch_in_gna.tf
#   aec_off_wov_str_def_1ch_in.tf
#   aec_off_wov_str_def_2ch_in.tf
#   aec_off_wov_str_def_4ch_in.tf
#   aec_wov_str_def_1ch_in.tf
#   aec_wov_str_def_2ch_in.tf
#   aec_wov_str_def_2ch_in_gna.tf
#   aec_wov_str_def_4ch_in.tf
#   aec_wov_str_def_4ch_in_gna.tf
#   DefaultConfigs.xml
#   str_1ch_in_1_out_bypass.tf
#   str_2ch_in_1_out_bypass.tf
#   str_4ch_in_1_out_bypass.tf
# ----------------------------------------
# Корневая директория: D:\LenovoDrivers\LenovoThinkbook16G6+IMH\Drivers from Saler\Audio\SST9870\AS\MultiPaOemDll
# Поддиректорий нет
# Файлы:
#   IntelHwKws_v2.dll
#   settingsHwKws.xml
#   WweConfigurationDll.dll
# ----------------------------------------
# Корневая директория: D:\LenovoDrivers\LenovoThinkbook16G6+IMH\Drivers from Saler\Audio\SST9870\Cfg
# Поддиректорий нет
# Файлы:
#   aec_wov_str_def_1ch_in.tf
#   aec_wov_str_def_2ch_in.tf
#   aec_wov_str_def_4ch_in.tf
#   str_1ch_in_1_out_bypass.tf
#   str_2ch_in_1_out_bypass.tf
#   str_4ch_in_1_out_bypass.tf
# ----------------------------------------
# Корневая директория: D:\LenovoDrivers\LenovoThinkbook16G6+IMH\Drivers from Saler\Audio\SST9870\Fw
# Поддиректорий нет
# Файлы:
#   dsp_fw_release.bin
# ----------------------------------------
# Корневая директория: D:\LenovoDrivers\LenovoThinkbook16G6+IMH\Drivers from Saler\Audio\SST9870\IntelMvaExtensionInf
# Поддиректорий нет
# Файлы:
#   IntelMva.dll
#   intelmvaextension.cat
#   IntelMvaExtension.inf
#   settings.xml
#   WweConfigurationDll.dll
# ----------------------------------------
# Корневая директория: D:\LenovoDrivers\LenovoThinkbook16G6+IMH\Drivers from Saler\Audio\SST9870\Libs
# Поддиректорий нет
# Файлы:
#   dsp_lib_intel_wov_release.bin
#   dsp_lib_nld_release.bin
#   dsp_lib_whm_release.bin
# ----------------------------------------
# Корневая директория: D:\LenovoDrivers\LenovoThinkbook16G6+IMH\Drivers from Saler\Audio\SST9870\Topology
# Поддиректорий нет
# Файлы:
#   IntcOEDTopology.oec
#   IntcOEDTopology.xml
# ----------------------------------------
# Корневая директория: D:\LenovoDrivers\LenovoThinkbook16G6+IMH\Drivers from Saler\Audio\SST9870\WoV
# Поддиректории:
#   Echo
#   Fuj
#   Leno2
#   Ms
#   Mslexa
#   Nec
#   Service
#   Tencent
#   Xiaomi
#   Yoga
# Файлы:
#   intelwov_data_manifest.txt
#   model_metadata_MTL.xml
# ----------------------------------------
# Корневая директория: D:\LenovoDrivers\LenovoThinkbook16G6+IMH\Drivers from Saler\Audio\SST9870\WoV\Echo
# Поддиректории:
#   m
# Файлов нет
# ----------------------------------------
# Корневая директория: D:\LenovoDrivers\LenovoThinkbook16G6+IMH\Drivers from Saler\Audio\SST9870\WoV\Echo\m
# Поддиректории:
#   de-AT
#   de-DE
#   en-AU
#   en-CA
#   en-GB
#   en-IN
#   en-NZ
#   en-US
#   es-ES
#   es-MX
#   es-US
#   fr-CA
#   fr-FR
#   it-IT
# ...
# Поддиректории:
#   Common
#   Engine
# Файлов нет
# ----------------------------------------
# Корневая директория: D:\U393\LenovoThinkbook16G6+IMH\Drivers from Saler\NVDIA_VGA\PhysX\files\Common
# Поддиректорий нет
# Файлы:
#   cudart32_65.dll
#   cudart64_65.dll
#   PhysXDevice.dll
#   PhysXDevice64.dll
#   PhysXLoader.dll
#   PhysXLoader64.dll
#   PhysXUpdateLoader.dll
#   PhysXUpdateLoader64.dll
# ----------------------------------------
# Корневая директория: D:\U393\LenovoThinkbook16G6+IMH\Drivers from Saler\NVDIA_VGA\PhysX\files\Engine
# Поддиректории:
#   07022E82A068
#   4F8D3BB436C7
#   5182B3C9EFEC
#   549B931E903E
#   6FE164B5308A
#   73BE2921551D
#   82D8704BAB07
#   86C5F4F22ECD
#   A0A1369354E1
#   B1E4CC1EB042
#   C22346819C37
#   F232A762B0C8
#   v2.7.1
#   v2.7.3
#   v2.7.4
#   v2.7.5
#   v2.7.6
#   v2.8.0
#   v2.8.1
#   v2.8.3
# Файлы:
#   A_Ball_Trans.ico
# ----------------------------------------
# Корневая директория: D:\U393\LenovoThinkbook16G6+IMH\Drivers from Saler\NVDIA_VGA\PhysX\files\Engine\07022E82A068
# Поддиректорий нет
# Файлы:
#   GRB_1_x86.dll
# ----------------------------------------
# Корневая директория: D:\U393\LenovoThinkbook16G6+IMH\Drivers from Saler\NVDIA_VGA\PhysX\files\Engine\4F8D3BB436C7
# Поддиректории:
#   ImplicitLibs
# Файлы:
#   APEX_ParticlesCHECKED_x86.dll
#   APEX_TurbulenceFSCHECKED_x86.dll
#   PhysXCore.dll
# ----------------------------------------
# Корневая директория: D:\U393\LenovoThinkbook16G6+IMH\Drivers from Saler\NVDIA_VGA\PhysX\files\Engine\4F8D3BB436C7\ImplicitLibs
# Поддиректорий нет
# Файлы:
#   PhysX3GpuCHECKED_x86.dll
# ----------------------------------------
# Корневая директория: D:\U393\LenovoThinkbook16G6+IMH\Drivers from Saler\NVDIA_VGA\PhysX\files\Engine\5182B3C9EFEC
# Поддиректорий нет
# Файлы:
#   PhysXCore.dll
# ----------------------------------------
# Корневая директория: D:\U393\LenovoThinkbook16G6+IMH\Drivers from Saler\NVDIA_VGA\PhysX\files\Engine\549B931E903E
# Поддиректорий нет
# Файлы:
#   PhysXCore.dll
# ----------------------------------------
# Корневая директория: D:\U393\LenovoThinkbook16G6+IMH\Drivers from Saler\NVDIA_VGA\PhysX\files\Engine\6FE164B5308A
# Поддиректорий нет
# Файлы:
#   PhysXCore.dll
# ----------------------------------------
# Корневая директория: D:\U393\LenovoThinkbook16G6+IMH\Drivers from Saler\NVDIA_VGA\PhysX\files\Engine\73BE2921551D
# Поддиректории:
#   ImplicitLibs
# Файлы:
#   APEX_BasicFSCHECKED_x86.dll
#   APEX_BasicIOSCHECKED_x86.dll
#   APEX_FieldSamplerCHECKED_x86.dll
#   APEX_IOFXCHECKED_x86.dll
#   APEX_TurbulenceFSCHECKED_x86.dll
#   PhysXCore.dll
# ----------------------------------------
# Корневая директория: D:\U393\LenovoThinkbook16G6+IMH\Drivers from Saler\NVDIA_VGA\PhysX\files\Engine\73BE2921551D\ImplicitLibs
# Поддиректорий нет
# Файлы:
#   cudart32_65.dll
#   PhysX3GpuCHECKED_x86.dll
# ----------------------------------------
# Корневая директория: D:\U393\LenovoThinkbook16G6+IMH\Drivers from Saler\NVDIA_VGA\PhysX\files\Engine\82D8704BAB07
# Поддиректорий нет
# Файлы:
#   PhysXCore.dll
# ----------------------------------------
# Корневая директория: D:\U393\LenovoThinkbook16G6+IMH\Drivers from Saler\NVDIA_VGA\PhysX\files\Engine\86C5F4F22ECD
# Поддиректории:
#   ImplicitLibs
# Файлы:
#   APEX_Particles_x64.dll
#   APEX_TurbulenceFS_x64.dll
# ----------------------------------------
# Корневая директория: D:\U393\LenovoThinkbook16G6+IMH\Drivers from Saler\NVDIA_VGA\PhysX\files\Engine\86C5F4F22ECD\ImplicitLibs
# Поддиректорий нет
# Файлы:
#   PhysX3Gpu_x64.dll
# ----------------------------------------
# Корневая директория: D:\U393\LenovoThinkbook16G6+IMH\Drivers from Saler\NVDIA_VGA\PhysX\files\Engine\A0A1369354E1
# Поддиректорий нет
# Файлы:
#   APEX_Particles_x86.dll
#   APEX_TurbulenceFS_x86.dll
#   PhysX3Gpu_x86.dll
# ----------------------------------------
# Корневая директория: D:\U393\LenovoThinkbook16G6+IMH\Drivers from Saler\NVDIA_VGA\PhysX\files\Engine\B1E4CC1EB042
# Поддиректорий нет
# Файлы:
#   PhysXCore.dll
# ----------------------------------------
# Корневая директория: D:\U393\LenovoThinkbook16G6+IMH\Drivers from Saler\NVDIA_VGA\PhysX\files\Engine\C22346819C37
# Поддиректорий нет
# Файлы:
#   PhysXCore.dll
# ----------------------------------------
# Корневая директория: D:\U393\LenovoThinkbook16G6+IMH\Drivers from Saler\NVDIA_VGA\PhysX\files\Engine\F232A762B0C8
# Поддиректорий нет
# Файлы:
#   PhysXCore.dll
# ----------------------------------------
# Корневая директория: D:\U393\LenovoThinkbook16G6+IMH\Drivers from Saler\NVDIA_VGA\PhysX\files\Engine\v2.7.1
# Поддиректорий нет
# Файлы:
#   NxCooking.dll
#   PhysXCore.dll
# ----------------------------------------
# Корневая директория: D:\U393\LenovoThinkbook16G6+IMH\Drivers from Saler\NVDIA_VGA\PhysX\files\Engine\v2.7.3
# Поддиректорий нет
# Файлы:
#   NxCooking.dll
#   PhysXCore.dll
# ----------------------------------------
# Корневая директория: D:\U393\LenovoThinkbook16G6+IMH\Drivers from Saler\NVDIA_VGA\PhysX\files\Engine\v2.7.4
# Поддиректорий нет
# Файлы:
#   NxCooking.dll
#   PhysXCore.dll
# ----------------------------------------
# Корневая директория: D:\U393\LenovoThinkbook16G6+IMH\Drivers from Saler\NVDIA_VGA\PhysX\files\Engine\v2.7.5
# Поддиректорий нет
# Файлы:
#   NxCooking.dll
#   PhysXCore.dll
# ----------------------------------------
# Корневая директория: D:\U393\LenovoThinkbook16G6+IMH\Drivers from Saler\NVDIA_VGA\PhysX\files\Engine\v2.7.6
# Поддиректорий нет
# Файлы:
#   NxCooking.dll
#   PhysXCore.dll
# ----------------------------------------
# Корневая директория: D:\U393\LenovoThinkbook16G6+IMH\Drivers from Saler\NVDIA_VGA\PhysX\files\Engine\v2.8.0
# Поддиректорий нет
# Файлы:
#   NxCooking.dll
#   PhysXCore.dll
# ----------------------------------------
# Корневая директория: D:\U393\LenovoThinkbook16G6+IMH\Drivers from Saler\NVDIA_VGA\PhysX\files\Engine\v2.8.1
# Поддиректорий нет
# Файлы:
#   NxCooking.dll
#   PhysXCore.dll
# ----------------------------------------
# Корневая директория: D:\U393\LenovoThinkbook16G6+IMH\Drivers from Saler\NVDIA_VGA\PhysX\files\Engine\v2.8.3
# Поддиректорий нет
# Файлы:
#   PhysXCooking.dll
#   PhysXCooking64.dll
#   PhysXCore.dll
#   PhysXCore64.dll
# ----------------------------------------
# Корневая директория: D:\U393\LenovoThinkbook16G6+IMH\Drivers from Saler\NVDIA_VGA\Update.Core
# Поддиректорий нет
# Файлы:
#   NvProfileUpdater64.exe
#   UpdateCore.nvi
#   UpdateCoreExt.dll
# ----------------------------------------
# Корневая директория: D:\U393\LenovoThinkbook16G6+IMH\Drivers from Saler\PMT
# Поддиректории:
#   Documents
#   RegistryKeys
# Файлы:
#   install.bat
#   intcpmt.cat
#   intcpmt.inf
#   IntcPMT.sys
# ----------------------------------------
# Корневая директория: D:\U393\LenovoThinkbook16G6+IMH\Drivers from Saler\PMT\Documents
# Поддиректории:
#   License
#   ReleaseNotes
# Файлов нет
# ----------------------------------------
# Корневая директория: D:\U393\LenovoThinkbook16G6+IMH\Drivers from Saler\PMT\Documents\License
# Поддиректорий нет
# Файлы:
#   Intel OBL Distribution (Commercial Use) License Agreement [v2022.12.20].pdf
# ----------------------------------------
# Корневая директория: D:\U393\LenovoThinkbook16G6+IMH\Drivers from Saler\PMT\Documents\ReleaseNotes
# Поддиректорий нет
# Файлы:
#   CHANGELOG.md
# ----------------------------------------
# Корневая директория: D:\U393\LenovoThinkbook16G6+IMH\Drivers from Saler\PMT\RegistryKeys
# Поддиректорий нет
# Файлы:
#   pmt_A_step_only_bugfix.reg
#   README_pmt_A_step_only_bugfix.txt
# ----------------------------------------
# Корневая директория: D:\U393\LenovoThinkbook16G6+IMH\Drivers from Saler\PPM
# Поддиректорий нет
# Файлы:
#   Install.bat
#   PPM-MTL-preview-v1004.20231025.ppkg
# ----------------------------------------
# Корневая директория: D:\U393\LenovoThinkbook16G6+IMH\Drivers from Saler\Sensor
# Поддиректории:
#   IshHeci
#   IshHeciExtensionTemplate
#   IshHidBus
#   IshHidMini
#   IshOed
# Файлы:
#   install.bat
# ----------------------------------------
# Корневая директория: D:\U393\LenovoThinkbook16G6+IMH\Drivers from Saler\Sensor\IshHeci
# Поддиректории:
#   x64
# Файлов нет
# ----------------------------------------
# Корневая директория: D:\U393\LenovoThinkbook16G6+IMH\Drivers from Saler\Sensor\IshHeci\x64
# Поддиректорий нет
# Файлы:
#   IshHeci.cat
#   IshHeci.inf
#   IshHeci.sys
#   OffloadItemRadarGesture.dll
#   OffloadItemRadarMHD.dll
#   OffloadItemService.exe
# ----------------------------------------
# Корневая директория: D:\U393\LenovoThinkbook16G6+IMH\Drivers from Saler\Sensor\IshHeciExtensionTemplate
# Поддиректории:
#   x64
# Файлов нет
# ----------------------------------------
# Корневая директория: D:\U393\LenovoThinkbook16G6+IMH\Drivers from Saler\Sensor\IshHeciExtensionTemplate\x64
# Поддиректорий нет
# Файлы:
#   IshHeciExtensionTemplate.cat
#   IshHeciExtensionTemplate.inf
# ----------------------------------------
# Корневая директория: D:\U393\LenovoThinkbook16G6+IMH\Drivers from Saler\Sensor\IshHidBus
# Поддиректории:
#   x64
# Файлов нет
# ----------------------------------------
# Корневая директория: D:\U393\LenovoThinkbook16G6+IMH\Drivers from Saler\Sensor\IshHidBus\x64
# Поддиректорий нет
# Файлы:
#   IshHidBus.cat
#   IshHidBus.inf
#   IshHidBus.sys
# ----------------------------------------
# Корневая директория: D:\U393\LenovoThinkbook16G6+IMH\Drivers from Saler\Sensor\IshHidMini
# Поддиректории:
#   x64
# Файлов нет
# ----------------------------------------
# Корневая директория: D:\U393\LenovoThinkbook16G6+IMH\Drivers from Saler\Sensor\IshHidMini\x64
# Поддиректорий нет
# Файлы:
#   IshHidMini.cat
#   IshHidMini.inf
#   IshHidMini.sys
# ----------------------------------------
# Корневая директория: D:\U393\LenovoThinkbook16G6+IMH\Drivers from Saler\Sensor\IshOed
# Поддиректории:
#   x64
# Файлов нет
# ----------------------------------------
# Корневая директория: D:\U393\LenovoThinkbook16G6+IMH\Drivers from Saler\Sensor\IshOed\x64
# Поддиректорий нет
# Файлы:
#   IshOed.cat
#   IshOed.inf
#   IshOed.sys
# ----------------------------------------
# Корневая директория: D:\U393\LenovoThinkbook16G6+IMH\Drivers from Saler\SerialIO
# Поддиректорий нет
# Файлы:
#   ialpss2_gpio2_mtl.cat
#   iaLPSS2_GPIO2_MTL.inf
#   iaLPSS2_GPIO2_MTL.sys
#   ialpss2_i2c_mtl.cat
#   iaLPSS2_I2C_MTL.inf
#   iaLPSS2_I2C_MTL.sys
#   ialpss2_i3c_mtl.cat
#   iaLPSS2_I3C_MTL.inf
#   iaLPSS2_I3C_MTL.sys
#   ialpss2_spi_mtl.cat
#   iaLPSS2_SPI_MTL.inf
#   iaLPSS2_SPI_MTL.sys
#   ialpss2_uart2_mtl.cat
#   iaLPSS2_UART2_MTL.inf
#   iaLPSS2_UART2_MTL.sys
#   install.bat
# ----------------------------------------
# Корневая директория: D:\U393\LenovoThinkbook16G6+IMH\Drivers from Saler\Tcon
# Поддиректорий нет
# Файлы:
#   install.bat
#   tcnperipheral64.cat
#   TcnPeripheral64.inf
#   TcnPeripheral64.sys
#   TcnPeripheral_Install.exe
# ----------------------------------------
# Корневая директория: D:\U393\LenovoThinkbook16G6+IMH\Drivers from Saler\WLAN
# Поддиректорий нет
# Файлы:
#   Install.bat
#   IntelIhvRouter04.dll
#   IntelIhvRouter08.dll
#   IntelIhvRouter10.dll
#   IntelIhvRouter12.dll
#   IntelIhvRouter14.dll
#   NETwaw12.sys
#   NETwaw14.sys
#   Netwfw04.dat
#   Netwfw08.dat
#   Netwfw10.dat
#   Netwfw12.dat
#   Netwfw14.dat
#   netwtw04.cat
#   Netwtw04.INF
#   NETwtw04.sys
#   netwtw08.cat
#   Netwtw08.INF
#   NETwtw08.sys
#   NETwtw10.sys
#   NETwtw12.sys
#   NETwtw14.sys
#   netwtw6e.cat
#   Netwtw6e.INF
# ----------------------------------------
# Корневая директория: D:\U393\LenovoThinkbook16G6+IMH\Drivers from Saler\ZeroTouchDriver
# Поддиректории:
#   SmaRes
#   x64
# Файлы:
#   advapi32.dll
#   gdi32.dll
#   iTin.Core.dll
#   iTin.Core.Hardware.dll
#   iTin.Core.Hardware.Specification.Dmi.dll
#   iTin.Core.Hardware.Specification.Smbios.dll
#   iTin.Core.Hardware.Specification.Tpm.dll
#   kernel32.dll
#   Lenovo.AssemblyValidation.Native.dll
#   Lenovo.Vantage.AddinInterface.dll
#   Lenovo.Vantage.RpcClient.dll
#   Lenovo.Vantage.RpcCommon.dll
#   Lenovo.VantageService.Utilities.dll
#   lnvsst.cat
#   LnvSST.dll
#   LnvSST.INF
#   MetricsDelivery.dll
#   MetricsTransfer.dll
#   mscoree.dll
#   msvcp140.dll
#   Newtonsoft.Json.dll
#   oleaut32.dll
#   shlwapi.dll
#   SmartSense.exe
#   SmartSenseController.exe
#   ThirdPartyNoticeForLnvSST.txt
#   user32.dll
#   UserSSCtrl.exe
#   vcruntime140.dll
#   vcruntime140_1.dll
#   wtsapi32.dll
# ----------------------------------------
# Корневая директория: D:\U393\LenovoThinkbook16G6+IMH\Drivers from Saler\ZeroTouchDriver\SmaRes
# Поддиректорий нет
# Файлы:
#   SMA_Warning.jpg
#   SMA_Warning.wav
# ----------------------------------------
# Корневая директория: D:\U393\LenovoThinkbook16G6+IMH\Drivers from Saler\ZeroTouchDriver\x64
# Поддиректорий нет
# Файлы:
#   VantageRpcClient.dll
# ----------------------------------------
# Корневая директория: D:\U393\LenovoThinkbook16G6+IMH\Fingerprint
# Поддиректорий нет
# Файлы:
#   Fingerprint-QPTG057FYYTDAPF0.exe
# ----------------------------------------
# Корневая директория: D:\U393\LenovoThinkbook16G6+IMH\HotKey
# Поддиректорий нет
# Файлы:
#   Fn-01LF0RAFAR2W6JB0.exe
# ----------------------------------------
# Корневая директория: D:\U393\LenovoThinkbook16G6+IMH\Intel dynamic technology
# Поддиректорий нет
# Файлы:
#   DTT-QPTG027F44VECPF0.exe
# ----------------------------------------
# Корневая директория: D:\U393\LenovoThinkbook16G6+IMH\Intel managment engine
# Поддиректорий нет
# Файлы:
#   MEI-QPTG047F0U4TEPF0.exe
# ----------------------------------------
# Корневая директория: D:\U393\LenovoThinkbook16G6+IMH\LAN
# Поддиректорий нет
# Файлы:
#   Lan-QPTG027FLUBKNPF0.exe
# ----------------------------------------
# Корневая директория: D:\U393\LenovoThinkbook16G6+IMH\Motherboard
# Поддиректорий нет
# Файлы:
#   Chipset-QPTG017FPF2BQPF0.exe
#   GNA-QPTG017FBC0BFPF0.exe
#   ISH-QPTG027FWYSQEQF0.exe
#   PMT-QPTG017F03F4YPF0.exe
#   SIO-QPTG017F5M1HLPF0.exe
#   T-Con-QPTG017FN4PUHWF0.exe
#   VPU-QPTG017FZ2CFHQF0.exe
#   ZeroTouch-QSZT0RAF40F0A0.exe
# ----------------------------------------
# Корневая директория: D:\U393\LenovoThinkbook16G6+IMH\Power
# Поддиректорий нет
# Файлы:
#   EM-WWE00NAE40.exe
#   Power-QPTG027FR9FFDPF0.exe
# ----------------------------------------
# Корневая директория: D:\U393\LenovoThinkbook16G6+IMH\ThinkVantage
# Поддиректорий нет
# Файлы:
#   system_update_5.07.0137.exe
# ----------------------------------------
# Корневая директория: D:\U393\LenovoThinkbook16G6+IMH\USB HID
# Поддиректорий нет
# Файлы:
#   HID-QPTG017FM51LPPF0.exe
# ----------------------------------------
# Корневая директория: D:\U393\LenovoThinkbook16G6+IMH\Videocard
# Поддиректорий нет
# Файлы:
#   IntelVGA-QPTG037FDTWZSPF0.exe
#   NVVGA-QPTG027FMGS1RPF0.exe
# ----------------------------------------
# Корневая директория: D:\U393\LenovoThinkbook16G6+IMH\WLAN
# Поддиректорий нет
# Файлы:
#   IntelWlan-QPTG037F3FL48PF0.exe
# ----------------------------------------
# Корневая директория: D:\U393\media
# Поддиректории:
#   The.Last.Thing.He.Told.Me.S01.1080p.ATVP.WEB-DL.DDP5.1.H.264-EniaHD
# Файлы:
#   Bymerang.2021.WEB-DL.1080p.ELEKTRI4KA.UNIONGANG.mkv
#   Greenland.2020.1080p.AMZN.WEB-DL.DDP5.1.H.264-NTG.mkv
#   Nightmare.Alley.2021.1080p_от New-Team.mkv
#   Tenet.2020.BDRip.2160p.HDR.seleZen.mkv
#   The Little Things.2021.WEB-DL.1080p.W.mkv
#   The.Adam.Project.2022.WEB-DL.1080p.seleZen.mkv
#   TheDeathOfStalin(2017)BDRip.1080p(Line-5.1+MVO+AVOx2).mkv
#   Uncharted.2022.WEB-DL.2160p.HDR.seleZen.mkv
#   Сахара.(2005).BDRip-AVC.[JPN].O.M.[-=DoMiNo=-].mkv
# ----------------------------------------
# Корневая директория: D:\U393\media\The.Last.Thing.He.Told.Me.S01.1080p.ATVP.WEB-DL.DDP5.1.H.264-EniaHD
# Поддиректорий нет
# Файлы:
#   The.Last.Thing.He.Told.Me.S01E01.Protect.Her.1080p.ATVP.WEB-DL.DDP5.1.H.264-EniaHD.mkv
#   The.Last.Thing.He.Told.Me.S01E02.The.Day.After.1080p.ATVP.WEB-DL.DDP5.1.H.264-EniaHD.mkv
#   The.Last.Thing.He.Told.Me.S01E03.Keep.Austin.Weird.1080p.ATVP.WEB-DL.DDP5.1.H.264-EniaHD.mkv
#   The.Last.Thing.He.Told.Me.S01E04.Witness.to.Your.Life.1080p.ATVP.WEB-DL.DDP5.1.H.264-EniaHD.mkv
#   The.Last.Thing.He.Told.Me.S01E05.The.Never.Dry.1080p.ATVP.WEB-DL.DDP5.1.H.264-EniaHD.mkv
#   The.Last.Thing.He.Told.Me.S01E06.When.We.Were.Young.1080p.ATVP.WEB-DL.DDP5.1.H.264-EniaHD.mkv
#   The.Last.Thing.He.Told.Me.S01E07.Sanctuary.1080p.ATVP.WEB-DL.DDP5.1.H.264-EniaHD.mkv
# ----------------------------------------
# Корневая директория: D:\U393\System Volume Information
# Поддиректории:
#   EDP
# Файлы:
#   IndexerVolumeGuid
#   WPSettings.dat
# ----------------------------------------
# Корневая директория: D:\U393\System Volume Information\EDP
# Поддиректории:
#   Recovery
# Файлов нет
# ----------------------------------------
# Корневая директория: D:\U393\System Volume Information\EDP\Recovery
# Поддиректорий нет
# Файлов нет
# ----------------------------------------

# %% [markdown]
# ### Работа с файлами

# %% [markdown]
# Python «из коробки» располагает достаточно широким набором инструментов для работы с файлами. Для того чтобы начать работать с файлом, надо его открыть с помощью команды специальной функции open.

# %%
f = open('path/to/file', 'filemode', encoding='utf8')

# %% [markdown]
# Результатом этой операции будет файл, в котором указатель текущей позиции поставлен на начало или конец файла.
#
# Перед тем, как мы начнём разбирать аргументы, хотелось бы заранее отметить, что указателем называется скорее метка, которая указывает на определённое место в файле. Указателей в классическом понимании программиста, как, например, в C или C++ в Python нет!

# %% [markdown]
# Давайте по порядку разберём все аргументы:
#
# path/to/file — путь к файлу может быть относительным или абсолютным. Можно указывать в Unix-стиле (path/to/file) или в Windows-стиле (path\to\file).
# filemode — режим, в котором файл нужно открывать.
#
#
# Записывается в виде строки, может принимать следующие значения:
#
# r — открыть на чтение (по умолчанию);
#
# w — перезаписать и открыть на запись (если файла нет, то он создастся);
#
# x — создать и открыть на запись (если уже есть — исключение);
#
# a — открыть на дозапись (указатель будет поставлен в конец);
#
# t — открыть в текстовом виде (по умолчанию);
#
# b — открыть в бинарном виде.
#
# encoding — указание, в какой кодировке файл записан (utf8, cp1251 и т. д.) По умолчанию стоит utf-8. При этом можно записывать кодировку как через дефис, так и без: utf-8 или utf8.

# %% [markdown]
# Открытие файла на запись является блокирующей операцией, то есть она останавливает работу нашей программы до того, пока файл не откроется.
#
# Теперь давайте поговорим про то, как записывать какую-либо информацию в файл.
#
# При открытии файла внутри него ставится указатель текущей позиции для чтения. При открытии в режиме чтения ('r') или записи ('w') указатель ставится на начало, в режиме 'a' (добавление новых записей в конец файла) — в конец.
#
# Откроем файл на запись и с помощью метода write запишем в него строку. В качестве результата метод write возвращает количество записанных символов.

# %%
f = open('test.txt', 'w', encoding='utf8')

# Запишем в файл строку
f.write("This is a test string\n")
f.write("This is a new string\n")

# %% [markdown]
# После вызова команды write ваши данные не сразу попадут и сохранятся в файл. Связано это с особенностями внутренней работы операционных систем. Если для вас критично своевременное попадание информации на жесткий диск компьютера, то после записи вызывайте f.flush() или закрывайте файл. Закрыть файл можно с помощью метода close().

# %%
# обязательно нужно закрыть файл иначе он будет заблокирован ОС
f.close()

# %% [markdown]
# Теперь давайте посмотрим, как читать данные из файла.
#
# Откроем файл для чтения, в который только что записали две строки:

# %%
f = open('test.txt', 'r', encoding='utf8')

# %% [markdown]
# Вот его содержимое на жестком диске:
#
#
# This is a test string
# This is a new string

# %% [markdown]
# После того, как файл открыт для чтения, мы можем читать из него данные.

# %% [markdown]
# f.read(n) — операция, читающая с текущего места n символов, если файл открыт в t режиме, или n байт, если файл открыт в b режиме, и возвращающая прочитанную информацию.

# %%
print(f.read(10)) # This is a

# %% [markdown]
# После прочтения указатель на содержимое остается на той позиции, где чтение закончилось. Если n не указать, будет прочитано «от печки», то есть от текущего места указателя и до самого конца файла.

# %%
# считали остаток файла
f.read() # test string\nThis is a new string\n

# %% [markdown]
# После работы обязательно закрываем файл:

# %%
# обязательно закрываем файл
f.close()

# %% [markdown]
# ### Чтение и запись построчно
#
# Зачастую с файлами удобнее работать построчно, поэтому для этого есть отдельные методы:
#
# writelines — записывает список строк в файл;
#
# readline — считывает из файла одну строку и возвращает её;
#
# readlines — считывает из файла все строки в список и возвращает их.
#
# Метод f.writelines(sequence) не будет сам за вас дописывать символ конца строки ('\n'), поэтому при необходимости его нужно прописать вручную.

# %%
f = open('test.txt', 'a', encoding='utf8') # открываем файл на дозапись

sequence = ["other string\n", "123\n", "test test\n"]
f.writelines(sequence) # берет строки из sequence и записывает в файл (без переносов)

f.close()

# %% [markdown]
# Попробуем теперь построчно считать файл с помощью readlines:

# %%
f = open('test.txt', 'r', encoding='utf8')

print(f.readlines()) # считывает все строки в список и возвращает список

f.close()

# %% [markdown]
# Метод f.readline() возвращает строку (символы от текущей позиции до символа переноса строки):

# %%
f = open('test.txt', 'r', encoding='utf8')

print(f.readline()) # This is a test string
print(f.read(4)) # This
print(f.readline()) # is a new string

f.close()

# %% [markdown]
# ### Файл как итератор
#
# Объект файл является итератором, поэтому его можно использовать в цикле for.

# %% [markdown]
# Для чего это нужно?
#
# Итераторы представляют собой такой объект, который вычисляет какие-то действия на каждом шаге, а не все сразу. На примере файла это выглядит примерно так. Предположим, у вас есть огромный текстовый файл, который весит несколько гигабайт. Если попытаться разом считать его полностью с помощью f.readlines(), то он будет загружен в вашу программу, в то время как переменная, в которую будет записан файл, станет весить столько же, сколько и объём считанного файла.
#
# В большинстве задач с обработкой текста он весь сразу не нужен, поэтому мы можем, например, считывать его построчно, обрабатывать строку и забывать из нашей программы, чтобы считать новую. Тогда весь файл огромного объема не будет «висеть» в памяти компьютера.
#
# Не стоит считывать файл полностью — в большинстве задач с обработкой текста весь файл разом читать не требуется. В таком случае с файлом работают построчно.

# %%
f = open('test.txt')  # можно перечислять строки в файле
for line in f:
    print(line, end='')

# This is a test string
# This is a new string
# other string
# 123
# test test

f.close()

# %% [markdown]
# Цикл for, как мы помним, — это цикл, который перебирает по очереди.

# %% [markdown]
# ### Менеджер контекста with
#
# После работы с файлом его необходимо закрыть с помощью метода close(). Файл освобождается для операционной системы (если он был открыт для записи), и другие приложения могут получать к нему доступ. Если не закрыть файл явно, то информация, записываемая в него, может быть утеряна, или файл может повредиться.
#
# Для явного указания места работы с файлом, а также чтобы не забывать закрывать файл после обработки, существует менеджер контекста with.

# %%
# В блоке менеджера контекста открытый файл «жив» и с ним можно работать, при выходе из блока - файл закрывается.
with open("test.txt", 'rb') as f:
    a = f.read(10)
    b = f.read(23)

f.read(3) # Error!

# %% [markdown]
# Тело менеджера контекста определяется одним отступом вправо относительно отступов ключевого слова with. Менеджер контекста неявно вызывает закрытие файла после работы, что освобождает вас от забот о том, закрыли ли вы файл или нет. Закрытие файла происходит при любом стечении обстоятельств, даже если внутри with будет ошибка.
#
# В дальнейшем мы научимся писать собственные структуры, работающие похожим образом.

# %% [markdown]
# ### Задание 7.4
# Задание на самопроверку.
#
# Создайте любой файл на операционной системе под название input.txt и построчно перепишите его в файл output.txt.

# %%
import os

with open("input.txt", 'r') as fi:
    with open("output.txt", 'w') as fo:
      for line in fi:
          fo.writelines(line)

# %% [markdown]
# ### Задание 7.5
# Задание на самопроверку.
#
# Дан файл numbers.txt, компоненты которого являются действительными числами (файл создайте самостоятельно и заполните любыми числам, в одной строке одно число). Найдите сумму наибольшего и наименьшего из значений и запишите результат в файл output.txt.

# %%
import random
import os

input_file = "input_75.txt"
ouput_file = "output_75.txt"

with open(input_file, 'w') as fi:
 for i in range(100):
     fi.write(str(float(i+random.randint(1, 100)/100)) + '\n')

summ = 0
min = None
max = None

with open(input_file, 'r') as fi:
 for line in fi:
    num = float(line)
    if min is None or num < min:
        min = num
    if max is None or num > max:
        max = num

print (min, max)
summ = max + min     
print(summ)
     
with open(ouput_file, 'w') as fo:
  fo.write(str(summ))
# Out:
# 0.55 99.27
# 99.82

# %% [markdown]
# ### Задание 7.6
# Задание на самопроверку.
#
# В текстовый файл построчно записаны фамилии и имена учащихся класса и их оценки за контрольную. Подсчитайте количество учащихся, чья оценка меньше 3 баллов. Cодержание файла:
#
# Иванов О. 4
# Петров И. 3
# Дмитриев Н. 2
# Смирнова О. 4
# Керченских В. 5
# Котов Д. 2
# Бирюкова Н. 1
# Данилов П. 3
# Аранских В. 5
# Лемонов Ю. 2
# Олегова К. 4

# %%
import os

input_file = "input_76.txt"
min_mark = 3
count = 0

with open(input_file, 'r', encoding='utf-8') as fi:
 for line in fi:
     mark = int(line.split()[-1])
     
     if mark < min_mark:
         count += 1

print(count)
# Out:
# 4

# %% [markdown]
# ### Задание 7.7
# Задание на самопроверку.
#
# Выполните реверсирование строк файла (перестановку строк файла в обратном порядке).

# %%
import os

input_file_name = "input_77.txt"
ouput_file_name = "output_77.txt"

          
with open(input_file_name, "r") as input_file:
    with open(ouput_file_name, "w") as output_file:
        for line in reversed(input_file.readlines()):
            output_file.write(line)

# %% [markdown]
# ## 8. Исключения

# %% [markdown]
# Предположим, мы написали программу. Она даже запустилась и вроде даже что-то сделала. Но в один прекрасный момент всё вылетело, а в терминале вылезло непонятное сообщение:

# %% [markdown]
# Traceback (most recent call last):
# File "<stdin>", line 1, in <module>
# ValueError: invalid literal for int() with base 10: "odin"

# %% [markdown]
# Эта ошибка относится к типу исключительных ситуаций. Исключительные ситуации порой возникают в случаях, когда вы написали код правильно, он запустился и отработал своё, а запустив код на следующий день, вы видите ошибку.
#
# ?
# Но как? В прошлый раз всё ведь запускалось без ошибок…
#
# Дело в том, что исключения могут возникнуть не только из-за ошибок в написании кода, а ещё и от взаимодействия пользователя с вашей программой, от состояния системы, на которой она запущена, погоды или ретроградного Меркурия. Да от чего угодно помимо вашего кода!

# %% [markdown]
# Итак, в этом юните вы узнаете, как работать с исключительными ситуациями или же исключениями в языке Python.

# %% [markdown]
# Исключения — это такие ошибки, которые возникают не во время компиляции программы, а в процессе её исполнения, в случаях, если что-то идёт не так.

# %% [markdown]
# После возникновения исключения программа попытается экстренно завершить работу или перейти к обработчику исключения, если такой есть. Поскольку Python — интерпретируемый язык, то, по сути, исключения и вставляют нам палки в колёса, прерывая выполнение программы.
#
# Ошибки бывают двух видов:
#
# __отлавливаемые__ — все, что наследуются от класса Exception;
#
# __не отлавливаемые__ — SystemExit, KeyboardInterrupt и т. д.
#
# Заучивать их все не стоит — только зря потратите время, потому как на самом деле этих ошибок может быть множество. Например, в отдельной библиотеке есть собственные исключения.
#
# Давайте же посмотрим на пример кода, который вызывает исключение.

# %% [markdown]
# Это лишь несколько из них. Список всех исключений доступен в документации. Можете ознакомиться с ним, чтобы быть в курсе, какие ошибки могут возникнуть в простых программах.

# %%
print("Перед исключением")
c = 1 / 0  # Здесь что-то не так….
print("После исключения")

# %% [markdown]
# В консоли мы увидим следующий результат:
#
# Перед исключением
# Traceback (most recent call last):
# File "<stdin>", line 1, in <module>
# ZeroDivisionError: division by zero
#
# Строка «После исключения» не будет выведена на экран: как только интерпретатор дойдёт до строчки c = 1 / 0, он экстренно завершит работу и выведет нам сообщение об ошибке деления на ноль.
#
# В этом примере мы чётко видим, что может возникнуть ошибка. Но в большинстве случаев это бывает не столь очевидно. Поэтому давайте слегка поменяем наш код:

# %% [markdown]
# Как же сделать так, чтобы программа не вылетала при ошибке и продолжала свою работу?
#
# Очень просто! Для этого и нужна конструкция try-except.
#
# Давайте посмотрим на следующий код:

# %%
try:  # Добавляем конструкцию try-except для отлова нашей ошибки
    print("Перед исключением")
    # теперь пользователь сам вводит числа для деления
    a = int(input("a: "))
    b = int(input("b: "))
    c = a / b  # здесь может возникнуть исключение деления на ноль
    print(c)  # печатаем c = a / b если всё хорошо
except ZeroDivisionError as e: # Добавляем тип именно той ошибки, которую хотим отловить.     
    print(e)  # Выводим информацию об ошибке
    print("После исключения")
 
print("После После исключения")
# Out:
# Перед исключением
# division by zero
# После исключения
# После После исключения

# %% [markdown]
# В данном случае тоже может возникнуть ошибка деления на ноль, если пользователь введёт b = 0. Поэтому мы отлавливаем ошибку ZeroDivisionError. В блоке try помещается «опасный» кусок кода, который может вызывать исключения, а в блоке except указывается класс ошибки, которую мы хотим отловить, а затем помещается код, который нужно выполнить в случае возникновении ошибки.
#
# После возникновении ошибки код в блоке try прервётся, перейдёт в блок except, а затем продолжит выполняться дальше — программа не вылетает, как это было без обработчика исключений. В этом и есть главная суть конструкции try-except.
#
# Это ещё не всё! Есть также блоки finally и else. Код в блоке else выполнялся после завершения цикла. С try-except есть нечто похожее. Посмотрите на пример кода ниже.

# %%
try:
    #*ваш код*
except Ошибка:
    #*Код отлова*
else:
    #*Код, который выполнится если всё хорошо прошло в блоке try*
finally:
    #*Код, который выполнится по любому*

# %% [markdown]
# Важно! Обратите внимание на отступы — код внутри конструкции сдвинут на второй уровень вложенности.

# %% [markdown]
# Давайте кратко подведём итоги:
#
# Исключения — это ошибки, которые выбрасываются при неправильной работе программы, и останавливают её выполнение, если они не обработаны.
# Конструкция try-except выглядит следующим образом и служит для обработки исключений:
# try:
#     *код, который может вызвать ту или иную ошибку*
# except *ошибка*:
#     *код, который выполнится в случае возникновения ошибки*
# else:
#     *код, который выполнится только в случае если в try ничего не сломалось*
# finally:
#     *код, который выполнится по любому*
# Блоки finally и else являются не обязательными, но могут быть использованы для вашего удобства. Код из блока finally выполняется в любом случае, независимо от исхода в блоках try-except. Код из блока else выполняется только в случае успешного выполнения кода в try.
# Выбрасывать ошибки можно и по своему желанию с помощью конструкции raise *Тип ошибки* (сообщение, которое нужно вывести в консоль).

# %% [markdown]
# ### Задание 8.7
# Задание на самопроверку.
#
# Создать скрипт, который будет в input() принимать строки, и их необходимо будет конвертировать в числа, добавить try-except на то, чтобы строки могли быть сконвертированы в числа.
#
# В случае удачного выполнения скрипта написать: «Вы ввели <введённое число>».
#
# В конце скрипта обязательно написать: «Выход из программы».
#
# ПРИМЕЧАНИЕ: Для отлова ошибок используйте try-except, а также блоки finally и else.

# %%
try:
    input_number = int(input("Введите число?"))
    
except ValueError as e:
    print("Вы ввели неправильное число")
else:
    print(f"Вы ввели {input_number}")
finally:
    print("Выход из программы")
# Out:
# Вы ввели 5
# Выход из программы

# %% [markdown]
# ## 9. Тонкости обработки исключений. Собственные классы исключений

# %% [markdown]
# Дисклеймер: этот материал попал к вам на страничку прямиком из пустыни Сахары, самого засушливого места на нашей планете. Если от сухости повествования у вас появится сухость во рту, не переживайте и не пугайтесь, это нормально. Такая уж тема, что тут поделать (чем дальше, тем суше, можно сказать). Поэтому, пожалуйста, заранее запаситесь прохладительными напитками и устраивайтесь поудобнее. Приятного прочтения!
#
# Вы уже знакомы с конструкцией try-except, научились отлавливать стандартные исключения и поднимать их при необходимости. В этом уроке мы закончим говорить об конструкции try-except, обсудим небольшие нюансы работы с ней, а также попробуем написать собственные классы-исключения.
#
# Пожалуйста, посмотрите на схему, представленную ниже.

# %% [markdown]
# BaseException
#  +-- SystemExit
#  +-- KeyboardInterrupt
#  +-- GeneratorExit
#  +-- Exception
#   	+-- StopIteration
#   	+-- StopAsyncIteration
#   	+-- ArithmeticError
#   	|	FloatingPointError
#   	|	OverflowError
#   	|	ZeroDivisionError
#   	+-- AssertionError
#   	+-- AttributeError
#   	+-- BufferError
#   	+-- EOFError
#   	+-- ImportError
#   	|	+-- ModuleNotFoundError
#   	+-- LookupError
#   	|	+-- IndexError
#   	|	+-- KeyError
#   	+-- MemoryError
#   	+-- NameError
#   	|	+-- UnboundLocalError
#   	+-- OSError
#   	|	+-- BlockingIOError
#   	|	+-- ChildProcessError
#   	|	+-- ConnectionError
#   	|	|	+-- BrokenPipeError
#   	|	|	+-- ConnectionAbortedError
#   	|	|	+-- ConnectionRefusedError
#   	|	|	+-- ConnectionResetError
#   	|	+-- FileExistsError
#   	|	+-- FileNotFoundError
#   	|	+-- InterruptedError
#   	|	+-- IsADirectoryError
#   	|	+-- NotADirectoryError
#   	|	+-- PermissionError
#   	|	+-- ProcessLookupError
#   	|	+-- TimeoutError
#   	+-- ReferenceError
#   	+-- RuntimeError
#   	|	+-- NotImplementedError
#   	|	+-- RecursionError
#   	+-- SyntaxError
#   	|	+-- IndentationError
#   	|     	+-- TabError
#   	+-- SystemError
#   	+-- TypeError
#   	+-- ValueError
#   	|	+-- UnicodeError
#   	|     	+-- UnicodeDecodeError
#   	|     	+-- UnicodeEncodeError
#   	|     	+-- UnicodeTranslateError
#   	+-- Warning
#        	+-- DeprecationWarning
#        	+-- PendingDeprecationWarning
#        	+-- RuntimeWarning
#        	+-- SyntaxWarning
#        	+-- UserWarning
#        	+-- FutureWarning
#        	+-- ImportWarning
#        	+-- UnicodeWarning
#        	+-- BytesWarning
#        	+-- ResourceWarning

# %% [markdown]
# Эта система — дерево стандартных исключений.
#
# Как нетрудно было догадаться, исключения представлены определёнными классами, которые в той или иной степени наследуются от BaseException.
#
# Классы +-- SystemExit +-- KeyboardInterrupt +-- GeneratorExit являются исключениями, которые нельзя поймать, поскольку их возникновение не зависит от выполнения программы. А все, что наследуются от Exception, можно отловить и обработать (хорошенько так). Однако некоторые из них возникают очень редко.
#
# Главное здесь — понять, что «ловить» в блоке except можно не только сам класс, но и его родителя, например:

# %%
try:
    raise ZeroDivisionError  # возбуждаем исключение ZeroDivisionError
except ArithmeticError:  # ловим его родителя
    print("Hello from arithmetic error")
# Out:
# Hello from arithmetic error

# %% [markdown]
# Такой способ отлова будет работать прекрасно. Но делать так не стоит, потому что вы рискуете упустить детали. С другой стороны, порой даже на больших проектах можно встретить что-то подобное:

# %%
# пример из реального проекта
try:
    #*код которые мог вызывать ошибку*
except Exception:
    pass

# %% [markdown]
# Иными словами, если что-то пошло не так, то мы просто закрываем на это глаза и идём дальше по коду. Код настоящего дзен-буддиста, что тут ещё скажешь.
#
# Действуя от обратного, однако, надо быть осторожным. Если, например, надо поймать несколько исключений, то идти следует вверх по дереву.

# %%
try:
    raise ZeroDivisionError
except ArithmeticError:
    print("Arithmetic error")
except ZeroDivisionError:
    print("Zero division error")
# Out:
# Arithmetic error

# %% [markdown]
# ArithmeticError является более абстрактным (находящимся выше в иерархическом дереве, родительским) классом. Если вы хотите ловить сначала исключения-потомки, а затем родительские исключения, убедитесь, что в блоке except отлов родительского исключения стоит ниже, чем отлов исключения-потомка. Иначе говоря, ваша конструкция отлова исключений должна идти от конкретного класса к более абстрактному.

# %% [markdown]
# Вот правильный пример для наглядности:

# %%
try:
    raise ZeroDivisionError
except ZeroDivisionError:  # сначала пытаемся поймать потомка
    print("Zero division error")
except ArithmeticError:  # потом ловим родителя
    print("Arithmetic error")
# Out:
# Zero division error

# %% [markdown]
# Это всё, что хотелось ещё рассказать о конструкции try-except.
#
# Если кратко обобщить, то можно сказать так: исключения — это тоже классы. Будучи классами, они могут наследоваться. «Отлавливать» можно как сам класс, так и его родителя (в любом колене). В этом случае надо убедиться в том, чтобы сначала обрабатывались более конкретные исключения, иначе они могут быть перекрыты их родителями и попросту упущены.
#
# Иногда может понадобиться написать собственное исключение. Например, вы пишете собственную игру и вам нужно обработать ситуацию, когда ваш персонаж пытается выучить способность, при этом не достигнув нужного уровня. Или пытается положить в уже заполненный инвентарь ещё какой-то предмет.
#
# Принцип написания и отлова собственного исключения следующий:

# %%
class MyException(Exception):  # создаём пустой класс исключения 
    pass

 
try:
    raise MyException("message")  # поднимаем наше исключение
except MyException as e:  # ловим его
    print(e)  # выводим информацию об исключении

# %% [markdown]
# Лучше всего, чтобы исключения были связаны между собой, то есть наследовались от общего класса исключения. Если продолжить пример с игрой из прошлого абзаца, то общим классом был бы GameplayException.
#
# Наследуются исключения для того, чтобы можно было, продолжая всё тот же пример, отлавливать отдельно игровые исключения и отдельно исключения, касающиеся ресурсов (закончилась оперативная память, место на диске и так далее).
#
# Давайте теперь попробуем построить собственные исключения с наследованием:

# %%
class ParentException(Exception):  # создаём пустой класс исключения, наследуемся от exception
    pass

 
class ChildException(ParentException):  # создаём пустой класс исключения-потомка, наследуемся от ParentException
    pass

 
try:
    raise ChildException("message")  # поднимаем исключение-потомок
except ParentException as e:  # ловим его родителя
    print(e)  # выводим информацию об исключении

# %% [markdown]
# В этом случае мы успешно обработали собственный класс-наследник, хотя он и не является ParentException. Когда исключение возникает, в каждом блоке except по порядку интерпретатор проверяет, является ли исключение наследником или самим классом отлавливаемого исключения, и если да, то выполняет код в except.
#
# Кстати говоря, класс с самописным исключением необязательно должен быть пустым. Если вы хотите добавить собственные аргументы в конструктор, дополнительно произвести какие-либо операции, то можете спокойно это делать, главное — не забыть о нескольких нюансах:

# %%
class ParentException(Exception):
    def __init__(self, message, error):  # допишем к нашему пустому классу конструктор, который будет печатать дополнительно в консоль информацию об ошибке.
        super().__init__(message)  # помним про вызов конструктора родительского класса
        print(f"Errors: {error}")  # печатаем ошибку

 
class ChildException(ParentException): # создаём пустой класс исключения-потомка, наследуемся от ParentException
    def __init__(self, message, error):
        super().__init__(message, error)
 
 
try:
    raise ChildException("message", "error")  # поднимаем исключение-потомок, передаём дополнительный аргумент
except ParentException as e:
    print(e)  # выводим информацию об исключении
# Out:
# Errors: error
# message

# %% [markdown]
# Сначала мы увидим то, что напишет нам конструктор родительского класса, а потом уже —сообщение об ошибке.
#
# Конечно же, собственный класс исключений можно модернизировать как угодно: добавлять дополнительные аргументы, писать собственные методы, наследоваться хоть до десятого колена и так далее. Суть одна — помните про иерархию и полиморфизм, остальное за вас сделает Python.

# %% [markdown]
# Давайте подведём итоги:
#
# Исключения — это такие особенные классы, которые, как и любые классы, можно наследовать. Если вы хотите ловить несколько исключений, то сначала ловите потомков, а потом родителей, чтобы ничего не упустить.
#
# Чтобы создать собственный класс, нужно просто написать пустой класс и наследовать его от класса Exception, этого будет достаточно.
#
# Необязательно «отлавливать» сам класс. При необходимости можно отлавливать его родителя, это тоже будет работать, но вы можете упустить важную информацию.

# %% [markdown]
# ### Задание 9.5
# Задание на самопроверку.
#
# Создайте класс Square. Добавьте в конструктор класса Square собственное исключение NonPositiveDigitException, унаследованное от ValueError, которое будет срабатывать каждый раз, когда сторона квадрата меньше или равна 0.

# %%
class NonPositiveDigitException(ValueError):
    pass

class Square:
    def __init__(self, side_length):
        if side_length <= 0:
            raise NonPositiveDigitException("Сторона квадрата должна быть положительным числом.")
        self.side_length = side_length

    def area(self):
        return self.side_length ** 2

    def perimeter(self):
        return 4 * self.side_length

# Пример использования:
try:
    square = Square(-5)
except NonPositiveDigitException as e:
    print(e)  # Вывод: Сторона квадрата должна быть положительным числом.
# Out:
# Сторона квадрата должна быть положительным числом.

# %% [markdown]
# ## 10. Итоги

# %% [markdown]
# ⭐️ Поздравляем! В результате работы, проделанной в этой модуле, мы узнали, что такое ООП.
#
# Мы познакомились с самой концепцией, узнали, что такое классы и объекты, чем они различаются, и как работать с ними в Python.
# Также мы выяснили, что такое полиморфизм, наследование, инкапсуляция и абстракция.
# Мы создали собственные классы исключений, которые могут быть нужны при написании и отладке полноценных проектов, а также поработали с файловым контекстным менеджером на примере чтения и записи информации.
# ООП является лишь одним из инструментов: оно может упростить решение ряда задач, но есть много ситуаций, где можно и нужно обходиться одними функциями и базовыми командами языка. Надеемся, эти знания вам пригодятся. Даже если вы не будете писать много своих классов в дальнейшем, то будете чувствовать себя увереннее при использовании сторонних библиотек.
